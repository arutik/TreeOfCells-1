# %% [markdown]
# # Robustness test - subsetting DE genes

# %%
import numpy as np
import pandas as pd
import scanpy.api as sc
import anndata
from sklearn.linear_model import LogisticRegression
import pickle
import bbknn
import anndata

from scipy.stats import wasserstein_distance
from scipy.stats import pearsonr
from scipy.spatial.distance import cosine

import matplotlib.pyplot as plt
import seaborn as sns
from math import factorial


sc.settings.verbosity = 3             # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.logging.print_versions()
sc.settings.set_figure_params(dpi=80)
# Out:
# scanpy==1.4 anndata==0.6.18 numpy==1.16.2 scipy==1.2.1 pandas==0.24.1 scikit-learn==0.20.3 statsmodels==0.9.0 python-igraph==0.7.1 louvain==0.6.1

# %% [markdown]
# ### Functions

# %%
def create_adatas_dicts(adata,celltype_column):
    adata_dict = {}
    cell_types = list(set(adata.obs[celltype_column]))
    print(len(cell_types),'cell types:', cell_types)
    for i in range(len(cell_types)):
          adata_dict[cell_types[i]] = adata[adata.obs[celltype_column] == cell_types[i]]
    return(adata_dict)

# %% [markdown]
# Distance calculating functions

# %%
# cosine similarity
def cosine_bw_2_cell_types(adatas_dict_tissue,celltype1,celltype2):
    if list(adatas_dict_tissue[celltype1].var_names) != list(adatas_dict_tissue[celltype2].var_names):
        print('gene lists across cell type tables are not the same')
        return
    else:
        av_vect_ct1 = []
        av_vect_ct2 = []
        for i in range(len(adatas_dict_tissue[celltype1].var_names)):
            #if i%10==0:
            #    print('on gene #',i)
            curr_vect_1 = list(adatas_dict_tissue[celltype1].X[:,i])
            curr_vect_2 = list(adatas_dict_tissue[celltype2].X[:,i])
            av_vect_ct1.append(np.mean(curr_vect_1))
            av_vect_ct2.append(np.mean(curr_vect_2))

        if np.linalg.norm(av_vect_ct1) > 0 and np.linalg.norm(av_vect_ct2) > 0:    # to avoid division by 0
            curr_cosine = cosine(av_vect_ct1,av_vect_ct2)
            return(curr_cosine)
        else:
            print("both specified cell types have expression vectors of zero - don't express any genes at all - returning None, check your data!")
            return(None)

# %%
# Wasserstein / Earth mover's distance
def wass_bw_2_cell_types_binned(adatas_dict_tissue,celltype1,celltype2,bin_size=1):
    max_counts = []
    min_counts = []
    if list(adatas_dict_tissue[celltype1].var_names) != list(adatas_dict_tissue[celltype2].var_names):
        print('gene lists across cell type tables are not the same')
        return
    else:
        curr_wass = []
        for i in range(len(adatas_dict_tissue[celltype1].var_names)):
            #if i%10==0:
            #    print('on gene #',i)
            curr_vect_1 = list(adatas_dict_tissue[celltype1].X[:,i])
            curr_vect_2 = list(adatas_dict_tissue[celltype2].X[:,i])
            # maximum count value across the 2 distributions
            curr_max_count = int(max(max(np.unique(adatas_dict_tissue[celltype1].X[:,i])),
                              max(np.unique(adatas_dict_tissue[celltype2].X[:,i]))))
            curr_min_count = int(min(min(np.unique(adatas_dict_tissue[celltype1].X[:,i])),
                              min(np.unique(adatas_dict_tissue[celltype2].X[:,i]))))
            max_counts.append(curr_max_count)
            min_counts.append(curr_min_count)
            #print('current maximum counts',curr_max_count)
            #print('current minimum counts',curr_min_count)
            if np.linalg.norm(curr_vect_1) > 0 and np.linalg.norm(curr_vect_2) > 0:    # to avoid division by 0
                # binning the distributions
                bin_number = int(np.ceil((curr_max_count - curr_min_count)/bin_size))
                #print(bin_number)
                curr_vect_1_binned = list(np.histogram(curr_vect_1,bin_number,density=True)[0])
                curr_vect_2_binned = list(np.histogram(curr_vect_2,bin_number,density=True)[0])
                #print(wasserstein_distance(curr_vect_1_binned,curr_vect_2_binned))
                curr_wass.append(wasserstein_distance(curr_vect_1_binned,curr_vect_2_binned))
        #print('maximum counts was', max(max_counts))
        #print('minimum counts was', min(min_counts))
        av_wass = np.mean(curr_wass)
        return(av_wass)

# %%
# Pearson's correlation
def pearson_bw_2_cell_types(adatas_dict_tissue,celltype1,celltype2):
    if list(adatas_dict_tissue[celltype1].var_names) != list(adatas_dict_tissue[celltype2].var_names):
        print('gene lists across cell type tables are not the same')
        return
    else:
        av_vect_ct1 = []
        av_vect_ct2 = []
        for i in range(len(adatas_dict_tissue[celltype1].var_names)):
            #if i%10==0:
            #    print('on gene #',i)
            curr_vect_1 = list(adatas_dict_tissue[celltype1].X[:,i])
            curr_vect_2 = list(adatas_dict_tissue[celltype2].X[:,i])
            av_vect_ct1.append(np.mean(curr_vect_1))
            av_vect_ct2.append(np.mean(curr_vect_2))

        if np.linalg.norm(av_vect_ct1) > 0 and np.linalg.norm(av_vect_ct2) > 0:    # to avoid division by 0
            curr_pearson = pearsonr(av_vect_ct1,av_vect_ct2)
            return(curr_pearson)
        else:
            print("both specified cell types have expression vectors of zero - don't express any genes at all - returning None, check your data!")
            return(None)

# %% [markdown]
# Functions creating actual dataframes
# <br>
# For caution these are separate

# %%
def create_df_cosine(adatas_dict_tissue):
    curr_matrix = np.zeros((len(adatas_dict_tissue),len(adatas_dict_tissue)))
    for i in range(len(adatas_dict_tissue)):
        for j in range(i):
            curr_matrix[i][j] = cosine_bw_2_cell_types(adatas_dict_tissue,
                                                     list(adatas_dict_tissue.keys())[i],
                                                     list(adatas_dict_tissue.keys())[j])
            curr_matrix[j][i] = curr_matrix[i][j]
            print('element', i, j, 'done (',list(adatas_dict_tissue.keys())[i],',',list(adatas_dict_tissue.keys())[j],')')
    dataframe = pd.DataFrame(data=curr_matrix, 
                             columns=list(adatas_dict_tissue.keys()),
                             index=list(adatas_dict_tissue.keys()))
    return(dataframe)

# %%
def create_df_wasserstein_binned(adatas_dict_tissue):
    curr_matrix = np.zeros((len(adatas_dict_tissue),len(adatas_dict_tissue)))
    for i in range(len(adatas_dict_tissue)):
        for j in range(i):
            curr_matrix[i][j] = wass_bw_2_cell_types_binned(adatas_dict_tissue,
                                                     list(adatas_dict_tissue.keys())[i],
                                                     list(adatas_dict_tissue.keys())[j])
            curr_matrix[j][i] = curr_matrix[i][j]
            print('element', i, j, 'done (',list(adatas_dict_tissue.keys())[i],',',list(adatas_dict_tissue.keys())[j],')')
    dataframe = pd.DataFrame(data=curr_matrix, 
                             columns=list(adatas_dict_tissue.keys()),
                             index=list(adatas_dict_tissue.keys()))
    return(dataframe)

# %%
def create_df_pearson(adatas_dict_tissue):
    curr_matrix = np.zeros((len(adatas_dict_tissue),len(adatas_dict_tissue)))
    for i in range(len(adatas_dict_tissue)):
        for j in range(i):
            curr_matrix[i][j] = pearson_bw_2_cell_types(adatas_dict_tissue,
                                                     list(adatas_dict_tissue.keys())[i],
                                                     list(adatas_dict_tissue.keys())[j])[0]
            curr_matrix[j][i] = curr_matrix[i][j]
            print('element', i, j, 'done (',list(adatas_dict_tissue.keys())[i],',',list(adatas_dict_tissue.keys())[j],')')
    dataframe = pd.DataFrame(data=curr_matrix, 
                             columns=list(adatas_dict_tissue.keys()),
                             index=list(adatas_dict_tissue.keys()))
    return(dataframe)

# %% [markdown]
# Selecting DE genes

# %%
# using logFC > 1 and FDR(p-value) < 5% cutoffs by default
def create_union_list_of_DE_genes(adata, celltype_column, logFC_min = 1.0, FDR_max = 0.05):
    curr_dict = {}
    union_DE_genes = []
    for celltype in list(set(adata.obs[celltype_column])):
        #print(celltype)
        celltype = str(celltype)
        curr_genes = (pd.DataFrame(data=adata.uns['rank_genes_groups']['names']))[celltype]
        curr_log2fold = (pd.DataFrame(data=adata.uns['rank_genes_groups']['logfoldchanges']))[celltype]
        curr_pvals = (pd.DataFrame(data=adata.uns['rank_genes_groups']['pvals']))[celltype]
        curr_dict[celltype] = pd.DataFrame(data={'genes':curr_genes, 'log2foldchange':curr_log2fold, 'pvals':curr_pvals})
        curr_dict[celltype] = curr_dict[celltype][curr_dict[celltype]['log2foldchange'] > logFC_min]
        curr_dict[celltype] = curr_dict[celltype][curr_dict[celltype]['pvals'] < FDR_max]            
        union_DE_genes.append(curr_dict[celltype]['genes'])
    union_DE_genes = list(set([item for sublist in union_DE_genes for item in sublist]))
    return(union_DE_genes)

# %% [markdown]
# ## Generating distance matrices

# %% [markdown]
# ### Documentation
#
# sc_to_dist(celltype_column_str, distance_list, name_str,
#                 filepath_X_csv=None, filepath_obs_csv=None, filepath_h5ad = None):
# <br>
# generates distance matrices from single cell RNA-seq data
# <br>
# <br>
# Input: scRNA-seq dataset, can be provided trough either an h5ad file or separate gene expression and annotation tables (if saved through rds file in R)
# <br>
# Output: 0 if correct and successful execution (distance matrices are saved in working directory), -1 otherwise
# <br>
# <br>
# Arguments:
# <br>
# 1. celltype_column_str: srt - name of the column containing cell type lables in the annotation table
# <br>
# 2. distance_list: list - list of distance names to be used to generate distance matrices
# <br>
#     available distances and their names: cosine similarity - input as eiter 'cosine' or 'cosine similarity'; Pearson's correlation - input as eiter 'Pearson's correlation' or 'correlation'; Wasserstein distance - input as either 'Wasserstein' or 'earth mover's distance'
# <br>
# 3. name_str: str - name of the organism or just a code used to name the saved file
# <br>
# 4. filepath_X_csv: optional, None - path to the file with gene expression table in csv format, tab delimited
# <br>
# 5. filepath_obs_csv: optional, None - path to the file with annotation table in csv format, tab delimited
# <br>
# 6. filepath_h5ad: optional, None - path to the h5ad file with scRNA-seq data
# <br>
# NOTE: out of arguments 4, 5 and 6 you have to provide either 4 and 5 or 6
# <br>
# 7. alpha: 0.8 - gene subsetting parameter, what proportion of genes to take into account for distance matrix calculation

# %% [markdown]
# ### Alpha - subsetting parameter (how many genes we are tsking from all DE genes)

# %%
# 80%
alpha = 0.8

# %%
def sc_to_dist_subset(celltype_column_str, distance_list, name_str,
               filepath_X_csv = None, filepath_obs_csv = None, filepath_h5ad = None, alpha=0.8):
    # don't forget to import stuff in the beginning and compile all other general functions
    # add tests/checks
    
    if filepath_h5ad == None:
        curr_X = pd.read_csv(filepath_X_csv, sep='\t')
        curr_obs = pd.read_csv(filepath_obs_csv, sep='\t')
        curr_adata = anndata.AnnData(X=curr_X.T,obs=curr_obs)
        for col in curr_obs.columns:
            curr_adata.obs[col] = curr_obs[col]
        print('adata object created, expression matrix dimensions:', curr_adata.X.shape)
    else:
        curr_adata = sc.read(filepath_h5ad)
        print('adata object created, expression matrix dimensions:', curr_adata.X.shape)
    curr_adata.obs[celltype_column_str] = curr_adata.obs[celltype_column_str].astype('category')
    sc.tl.rank_genes_groups(curr_adata,celltype_column_str,method='wilcoxon')
    DE_genes = create_union_list_of_DE_genes(curr_adata,celltype_column_str)
    
    print('randomly selecting a proportion (alpha) of genes') 
    np.random.shuffle(DE_genes)
    print('list of ', int(alpha*100),'% of all DE genes (', len(DE_genes),' ) created, of total initial', 
          len(list(curr_adata.var_names)), 'genes')
    DE_genes = DE_genes[:round(alpha*len(DE_genes))]
    print('a snippet of DE_genes subset:',DE_genes[:5])
    
    # subsetting the adata object
    curr_adata = curr_adata[:,[i in DE_genes for i in curr_adata.var_names]]
    print('adata object subsetted to DE genes only, dimensions:', curr_adata.X.shape)
    
    curr_adata_dict = create_adatas_dicts(curr_adata, celltype_column_str)
    
    for distance in distance_list:
        if distance == 'cosine' or distance == 'cosine similarity':
            print('creating cosine similarity distance matrix')
            df_DE_cosine = create_df_cosine(curr_adata_dict)
            df_DE_cosine.to_csv(name_str+'_cosine_dist_matrix_DE_subset'+str(alpha)+'.csv',sep='\t')
            print('saved cosine matrix to ',name_str+'_cosine_dist_matrix_DE_subset'+str(alpha)+'.csv')
        elif distance == "Pearson's correlation" or distance == 'correlation':
            print("creating Pearson's correlation distance matrix")
            df_DE_pearson = create_df_pearson(curr_adata_dict)
            df_DE_pearson.to_csv(name_str+'_pearson_dist_matrix_DE_subset'+str(alpha)+'.csv',sep='\t')    
            print("saved Pearson's correlation matrix to ',name_str+'_pearson_dist_matrix_DE_subset"+str(alpha)+".csv")
        elif distance == 'Wasserstein' or distance == "earth mover's distance":
            print("creating Wasserstein (earth mover's) distance distance matrix")            
            df_DE_wasserstein = create_df_wasserstein_binned(curr_adata_dict)
            df_DE_wasserstein.to_csv(name_str+'_wasserstein_dist_matrix_DE_subset'+str(alpha)+'.csv',sep='\t')
            print('saved Wasserstein matrix to ',name_str+'_wasserstein_dist_matrix_DE_subset'+str(alpha)+'.csv')
    return(0)

# %%
# %%time
# trying out for mouse, cosine
sc_to_dist_subset('celltype',['cosine'],'mouse',filepath_h5ad='/home/jovyan/notebooks/Tree_of_Cells/Mouse_devo.h5ad')
# Out:
# adata object created, expression matrix dimensions: (9227, 29452)
# ranking genes
#     finished (0:01:04.73) --> added to `.uns['rank_genes_groups']`
#     'names', sorted np.recarray to be indexed by group ids
#     'scores', sorted np.recarray to be indexed by group ids
#     'logfoldchanges', sorted np.recarray to be indexed by group ids
#     'pvals', sorted np.recarray to be indexed by group ids
#     'pvals_adj', sorted np.recarray to be indexed by group ids
# randomly selecting a proportion (alpha) of genes
# list of  80 % of all DE genes ( 1153  ) created, of total initial 29452 genes
# adata object subsetted to DE genes only, dimensions: (9227, 922)
# 34 cell types: ['Blood progenitors 2', 'Surface ectoderm', 'Caudal neurectoderm', 'Rostral neurectoderm', 'Neural crest', 'Cardiomyocytes', 'Pharyngeal mesoderm', 'Nascent mesoderm', 'Haematoendothelial progenitors', 'Caudal epiblast', 'Caudal Mesoderm', 'Anterior Primitive Streak', 'Blood progenitors 1', 'Allantois', 'PGC', 'Forebrain/Midbrain/Hindbrain', 'Mesenchyme', 'Primitive Streak', 'Parietal endoderm', 'Endothelium', 'Spinal cord', 'Erythroid3', 'Mixed mesoderm', 'Paraxial mesoderm', 'Def. endoderm', 'NMP', 'Epiblast', 'Erythroid1', 'Visceral endoderm', 'Gut', 'Notochord', 'Erythroid2', 'Intermediate mesoderm', 'Somitic mesoderm']
# creating cosine similarity distance matrix
# element 1 0 done ( Surface ectoderm , Blood progenitors 2 )
# element 2 0 done ( Caudal neurectoderm , Blood progenitors 2 )
# element 2 1 done ( Caudal neurectoderm , Surface ectoderm )
# element 3 0 done ( Rostral neurectoderm , Blood progenitors 2 )
# element 3 1 done ( Rostral neurectoderm , Surface ectoderm )
# element 3 2 done ( Rostral neurectoderm , Caudal neurectoderm )
# element 4 0 done ( Neural crest , Blood progenitors 2 )
# element 4 1 done ( Neural crest , Surface ectoderm )
# element 4 2 done ( Neural crest , Caudal neurectoderm )
# element 4 3 done ( Neural crest , Rostral neurectoderm )
# element 5 0 done ( Cardiomyocytes , Blood progenitors 2 )
# element 5 1 done ( Cardiomyocytes , Surface ectoderm )
# element 5 2 done ( Cardiomyocytes , Caudal neurectoderm )
# element 5 3 done ( Cardiomyocytes , Rostral neurectoderm )
# element 5 4 done ( Cardiomyocytes , Neural crest )
# element 6 0 done ( Pharyngeal mesoderm , Blood progenitors 2 )
# element 6 1 done ( Pharyngeal mesoderm , Surface ectoderm )
# element 6 2 done ( Pharyngeal mesoderm , Caudal neurectoderm )
# element 6 3 done ( Pharyngeal mesoderm , Rostral neurectoderm )
# element 6 4 done ( Pharyngeal mesoderm , Neural crest )
# element 6 5 done ( Pharyngeal mesoderm , Cardiomyocytes )
# element 7 0 done ( Nascent mesoderm , Blood progenitors 2 )
# element 7 1 done ( Nascent mesoderm , Surface ectoderm )
# element 7 2 done ( Nascent mesoderm , Caudal neurectoderm )
# element 7 3 done ( Nascent mesoderm , Rostral neurectoderm )
# element 7 4 done ( Nascent mesoderm , Neural crest )
# element 7 5 done ( Nascent mesoderm , Cardiomyocytes )
# element 7 6 done ( Nascent mesoderm , Pharyngeal mesoderm )
# element 8 0 done ( Haematoendothelial progenitors , Blood progenitors 2 )
# element 8 1 done ( Haematoendothelial progenitors , Surface ectoderm )
# element 8 2 done ( Haematoendothelial progenitors , Caudal neurectoderm )
# element 8 3 done ( Haematoendothelial progenitors , Rostral neurectoderm )
# element 8 4 done ( Haematoendothelial progenitors , Neural crest )
# element 8 5 done ( Haematoendothelial progenitors , Cardiomyocytes )
# element 8 6 done ( Haematoendothelial progenitors , Pharyngeal mesoderm )
# element 8 7 done ( Haematoendothelial progenitors , Nascent mesoderm )
# element 9 0 done ( Caudal epiblast , Blood progenitors 2 )
# element 9 1 done ( Caudal epiblast , Surface ectoderm )
# element 9 2 done ( Caudal epiblast , Caudal neurectoderm )
# element 9 3 done ( Caudal epiblast , Rostral neurectoderm )
# element 9 4 done ( Caudal epiblast , Neural crest )
# element 9 5 done ( Caudal epiblast , Cardiomyocytes )
# element 9 6 done ( Caudal epiblast , Pharyngeal mesoderm )
# element 9 7 done ( Caudal epiblast , Nascent mesoderm )
# element 9 8 done ( Caudal epiblast , Haematoendothelial progenitors )
# element 10 0 done ( Caudal Mesoderm , Blood progenitors 2 )
# element 10 1 done ( Caudal Mesoderm , Surface ectoderm )
# element 10 2 done ( Caudal Mesoderm , Caudal neurectoderm )
# element 10 3 done ( Caudal Mesoderm , Rostral neurectoderm )
# element 10 4 done ( Caudal Mesoderm , Neural crest )
# element 10 5 done ( Caudal Mesoderm , Cardiomyocytes )
# element 10 6 done ( Caudal Mesoderm , Pharyngeal mesoderm )
# element 10 7 done ( Caudal Mesoderm , Nascent mesoderm )
# element 10 8 done ( Caudal Mesoderm , Haematoendothelial progenitors )
# element 10 9 done ( Caudal Mesoderm , Caudal epiblast )
# element 11 0 done ( Anterior Primitive Streak , Blood progenitors 2 )
# element 11 1 done ( Anterior Primitive Streak , Surface ectoderm )
# element 11 2 done ( Anterior Primitive Streak , Caudal neurectoderm )
# element 11 3 done ( Anterior Primitive Streak , Rostral neurectoderm )
# element 11 4 done ( Anterior Primitive Streak , Neural crest )
# element 11 5 done ( Anterior Primitive Streak , Cardiomyocytes )
# element 11 6 done ( Anterior Primitive Streak , Pharyngeal mesoderm )
# element 11 7 done ( Anterior Primitive Streak , Nascent mesoderm )
# element 11 8 done ( Anterior Primitive Streak , Haematoendothelial progenitors )
# element 11 9 done ( Anterior Primitive Streak , Caudal epiblast )
# element 11 10 done ( Anterior Primitive Streak , Caudal Mesoderm )
# element 12 0 done ( Blood progenitors 1 , Blood progenitors 2 )
# element 12 1 done ( Blood progenitors 1 , Surface ectoderm )
# element 12 2 done ( Blood progenitors 1 , Caudal neurectoderm )
# element 12 3 done ( Blood progenitors 1 , Rostral neurectoderm )
# element 12 4 done ( Blood progenitors 1 , Neural crest )
# element 12 5 done ( Blood progenitors 1 , Cardiomyocytes )
# element 12 6 done ( Blood progenitors 1 , Pharyngeal mesoderm )
# element 12 7 done ( Blood progenitors 1 , Nascent mesoderm )
# element 12 8 done ( Blood progenitors 1 , Haematoendothelial progenitors )
# element 12 9 done ( Blood progenitors 1 , Caudal epiblast )
# element 12 10 done ( Blood progenitors 1 , Caudal Mesoderm )
# element 12 11 done ( Blood progenitors 1 , Anterior Primitive Streak )
# element 13 0 done ( Allantois , Blood progenitors 2 )
# element 13 1 done ( Allantois , Surface ectoderm )
# element 13 2 done ( Allantois , Caudal neurectoderm )
# element 13 3 done ( Allantois , Rostral neurectoderm )
# element 13 4 done ( Allantois , Neural crest )
# element 13 5 done ( Allantois , Cardiomyocytes )
# element 13 6 done ( Allantois , Pharyngeal mesoderm )
# element 13 7 done ( Allantois , Nascent mesoderm )
# element 13 8 done ( Allantois , Haematoendothelial progenitors )
# element 13 9 done ( Allantois , Caudal epiblast )
# element 13 10 done ( Allantois , Caudal Mesoderm )
# element 13 11 done ( Allantois , Anterior Primitive Streak )
# element 13 12 done ( Allantois , Blood progenitors 1 )
# element 14 0 done ( PGC , Blood progenitors 2 )
# element 14 1 done ( PGC , Surface ectoderm )
# element 14 2 done ( PGC , Caudal neurectoderm )
# element 14 3 done ( PGC , Rostral neurectoderm )
# element 14 4 done ( PGC , Neural crest )
# element 14 5 done ( PGC , Cardiomyocytes )
# element 14 6 done ( PGC , Pharyngeal mesoderm )
# element 14 7 done ( PGC , Nascent mesoderm )
# element 14 8 done ( PGC , Haematoendothelial progenitors )
# element 14 9 done ( PGC , Caudal epiblast )
# element 14 10 done ( PGC , Caudal Mesoderm )
# element 14 11 done ( PGC , Anterior Primitive Streak )
# element 14 12 done ( PGC , Blood progenitors 1 )
# element 14 13 done ( PGC , Allantois )
# element 15 0 done ( Forebrain/Midbrain/Hindbrain , Blood progenitors 2 )
# element 15 1 done ( Forebrain/Midbrain/Hindbrain , Surface ectoderm )
# element 15 2 done ( Forebrain/Midbrain/Hindbrain , Caudal neurectoderm )
# element 15 3 done ( Forebrain/Midbrain/Hindbrain , Rostral neurectoderm )
# element 15 4 done ( Forebrain/Midbrain/Hindbrain , Neural crest )
# element 15 5 done ( Forebrain/Midbrain/Hindbrain , Cardiomyocytes )
# element 15 6 done ( Forebrain/Midbrain/Hindbrain , Pharyngeal mesoderm )
# element 15 7 done ( Forebrain/Midbrain/Hindbrain , Nascent mesoderm )
# element 15 8 done ( Forebrain/Midbrain/Hindbrain , Haematoendothelial progenitors )
# element 15 9 done ( Forebrain/Midbrain/Hindbrain , Caudal epiblast )
# element 15 10 done ( Forebrain/Midbrain/Hindbrain , Caudal Mesoderm )
# element 15 11 done ( Forebrain/Midbrain/Hindbrain , Anterior Primitive Streak )
# element 15 12 done ( Forebrain/Midbrain/Hindbrain , Blood progenitors 1 )
# element 15 13 done ( Forebrain/Midbrain/Hindbrain , Allantois )
# element 15 14 done ( Forebrain/Midbrain/Hindbrain , PGC )
# element 16 0 done ( Mesenchyme , Blood progenitors 2 )
# element 16 1 done ( Mesenchyme , Surface ectoderm )
# element 16 2 done ( Mesenchyme , Caudal neurectoderm )
# element 16 3 done ( Mesenchyme , Rostral neurectoderm )
# element 16 4 done ( Mesenchyme , Neural crest )
# element 16 5 done ( Mesenchyme , Cardiomyocytes )
# element 16 6 done ( Mesenchyme , Pharyngeal mesoderm )
# element 16 7 done ( Mesenchyme , Nascent mesoderm )
# element 16 8 done ( Mesenchyme , Haematoendothelial progenitors )
# element 16 9 done ( Mesenchyme , Caudal epiblast )
# element 16 10 done ( Mesenchyme , Caudal Mesoderm )
# element 16 11 done ( Mesenchyme , Anterior Primitive Streak )
# element 16 12 done ( Mesenchyme , Blood progenitors 1 )
# element 16 13 done ( Mesenchyme , Allantois )
# element 16 14 done ( Mesenchyme , PGC )
# element 16 15 done ( Mesenchyme , Forebrain/Midbrain/Hindbrain )
# element 17 0 done ( Primitive Streak , Blood progenitors 2 )
# element 17 1 done ( Primitive Streak , Surface ectoderm )
# element 17 2 done ( Primitive Streak , Caudal neurectoderm )
# element 17 3 done ( Primitive Streak , Rostral neurectoderm )
# element 17 4 done ( Primitive Streak , Neural crest )
# element 17 5 done ( Primitive Streak , Cardiomyocytes )
# element 17 6 done ( Primitive Streak , Pharyngeal mesoderm )
# element 17 7 done ( Primitive Streak , Nascent mesoderm )
# element 17 8 done ( Primitive Streak , Haematoendothelial progenitors )
# element 17 9 done ( Primitive Streak , Caudal epiblast )
# element 17 10 done ( Primitive Streak , Caudal Mesoderm )
# element 17 11 done ( Primitive Streak , Anterior Primitive Streak )
# element 17 12 done ( Primitive Streak , Blood progenitors 1 )
# element 17 13 done ( Primitive Streak , Allantois )
# element 17 14 done ( Primitive Streak , PGC )
# element 17 15 done ( Primitive Streak , Forebrain/Midbrain/Hindbrain )
# element 17 16 done ( Primitive Streak , Mesenchyme )
# element 18 0 done ( Parietal endoderm , Blood progenitors 2 )
# element 18 1 done ( Parietal endoderm , Surface ectoderm )
# element 18 2 done ( Parietal endoderm , Caudal neurectoderm )
# element 18 3 done ( Parietal endoderm , Rostral neurectoderm )
# element 18 4 done ( Parietal endoderm , Neural crest )
# element 18 5 done ( Parietal endoderm , Cardiomyocytes )
# element 18 6 done ( Parietal endoderm , Pharyngeal mesoderm )
# element 18 7 done ( Parietal endoderm , Nascent mesoderm )
# element 18 8 done ( Parietal endoderm , Haematoendothelial progenitors )
# element 18 9 done ( Parietal endoderm , Caudal epiblast )
# element 18 10 done ( Parietal endoderm , Caudal Mesoderm )
# element 18 11 done ( Parietal endoderm , Anterior Primitive Streak )
# element 18 12 done ( Parietal endoderm , Blood progenitors 1 )
# element 18 13 done ( Parietal endoderm , Allantois )
# element 18 14 done ( Parietal endoderm , PGC )
# element 18 15 done ( Parietal endoderm , Forebrain/Midbrain/Hindbrain )
# element 18 16 done ( Parietal endoderm , Mesenchyme )
# element 18 17 done ( Parietal endoderm , Primitive Streak )
# element 19 0 done ( Endothelium , Blood progenitors 2 )
# element 19 1 done ( Endothelium , Surface ectoderm )
# element 19 2 done ( Endothelium , Caudal neurectoderm )
# element 19 3 done ( Endothelium , Rostral neurectoderm )
# element 19 4 done ( Endothelium , Neural crest )
# element 19 5 done ( Endothelium , Cardiomyocytes )
# element 19 6 done ( Endothelium , Pharyngeal mesoderm )
# element 19 7 done ( Endothelium , Nascent mesoderm )
# element 19 8 done ( Endothelium , Haematoendothelial progenitors )
# element 19 9 done ( Endothelium , Caudal epiblast )
# element 19 10 done ( Endothelium , Caudal Mesoderm )
# element 19 11 done ( Endothelium , Anterior Primitive Streak )
# element 19 12 done ( Endothelium , Blood progenitors 1 )
# element 19 13 done ( Endothelium , Allantois )
# element 19 14 done ( Endothelium , PGC )
# element 19 15 done ( Endothelium , Forebrain/Midbrain/Hindbrain )
# element 19 16 done ( Endothelium , Mesenchyme )
# element 19 17 done ( Endothelium , Primitive Streak )
# element 19 18 done ( Endothelium , Parietal endoderm )
# element 20 0 done ( Spinal cord , Blood progenitors 2 )
# element 20 1 done ( Spinal cord , Surface ectoderm )
# element 20 2 done ( Spinal cord , Caudal neurectoderm )
# element 20 3 done ( Spinal cord , Rostral neurectoderm )
# element 20 4 done ( Spinal cord , Neural crest )
# element 20 5 done ( Spinal cord , Cardiomyocytes )
# element 20 6 done ( Spinal cord , Pharyngeal mesoderm )
# element 20 7 done ( Spinal cord , Nascent mesoderm )
# element 20 8 done ( Spinal cord , Haematoendothelial progenitors )
# element 20 9 done ( Spinal cord , Caudal epiblast )
# element 20 10 done ( Spinal cord , Caudal Mesoderm )
# element 20 11 done ( Spinal cord , Anterior Primitive Streak )
# element 20 12 done ( Spinal cord , Blood progenitors 1 )
# element 20 13 done ( Spinal cord , Allantois )
# element 20 14 done ( Spinal cord , PGC )
# element 20 15 done ( Spinal cord , Forebrain/Midbrain/Hindbrain )
# element 20 16 done ( Spinal cord , Mesenchyme )
# element 20 17 done ( Spinal cord , Primitive Streak )
# element 20 18 done ( Spinal cord , Parietal endoderm )
# element 20 19 done ( Spinal cord , Endothelium )
# element 21 0 done ( Erythroid3 , Blood progenitors 2 )
# element 21 1 done ( Erythroid3 , Surface ectoderm )
# element 21 2 done ( Erythroid3 , Caudal neurectoderm )
# element 21 3 done ( Erythroid3 , Rostral neurectoderm )
# element 21 4 done ( Erythroid3 , Neural crest )
# element 21 5 done ( Erythroid3 , Cardiomyocytes )
# element 21 6 done ( Erythroid3 , Pharyngeal mesoderm )
# element 21 7 done ( Erythroid3 , Nascent mesoderm )
# element 21 8 done ( Erythroid3 , Haematoendothelial progenitors )
# element 21 9 done ( Erythroid3 , Caudal epiblast )
# element 21 10 done ( Erythroid3 , Caudal Mesoderm )
# element 21 11 done ( Erythroid3 , Anterior Primitive Streak )
# element 21 12 done ( Erythroid3 , Blood progenitors 1 )
# element 21 13 done ( Erythroid3 , Allantois )
# element 21 14 done ( Erythroid3 , PGC )
# element 21 15 done ( Erythroid3 , Forebrain/Midbrain/Hindbrain )
# element 21 16 done ( Erythroid3 , Mesenchyme )
# element 21 17 done ( Erythroid3 , Primitive Streak )
# element 21 18 done ( Erythroid3 , Parietal endoderm )
# element 21 19 done ( Erythroid3 , Endothelium )
# element 21 20 done ( Erythroid3 , Spinal cord )
# element 22 0 done ( Mixed mesoderm , Blood progenitors 2 )
# element 22 1 done ( Mixed mesoderm , Surface ectoderm )
# element 22 2 done ( Mixed mesoderm , Caudal neurectoderm )
# element 22 3 done ( Mixed mesoderm , Rostral neurectoderm )
# element 22 4 done ( Mixed mesoderm , Neural crest )
# element 22 5 done ( Mixed mesoderm , Cardiomyocytes )
# element 22 6 done ( Mixed mesoderm , Pharyngeal mesoderm )
# element 22 7 done ( Mixed mesoderm , Nascent mesoderm )
# element 22 8 done ( Mixed mesoderm , Haematoendothelial progenitors )
# element 22 9 done ( Mixed mesoderm , Caudal epiblast )
# element 22 10 done ( Mixed mesoderm , Caudal Mesoderm )
# element 22 11 done ( Mixed mesoderm , Anterior Primitive Streak )
# element 22 12 done ( Mixed mesoderm , Blood progenitors 1 )
# element 22 13 done ( Mixed mesoderm , Allantois )
# element 22 14 done ( Mixed mesoderm , PGC )
# element 22 15 done ( Mixed mesoderm , Forebrain/Midbrain/Hindbrain )
# element 22 16 done ( Mixed mesoderm , Mesenchyme )
# element 22 17 done ( Mixed mesoderm , Primitive Streak )
# element 22 18 done ( Mixed mesoderm , Parietal endoderm )
# element 22 19 done ( Mixed mesoderm , Endothelium )
# element 22 20 done ( Mixed mesoderm , Spinal cord )
# element 22 21 done ( Mixed mesoderm , Erythroid3 )
# element 23 0 done ( Paraxial mesoderm , Blood progenitors 2 )
# element 23 1 done ( Paraxial mesoderm , Surface ectoderm )
# element 23 2 done ( Paraxial mesoderm , Caudal neurectoderm )
# element 23 3 done ( Paraxial mesoderm , Rostral neurectoderm )
# element 23 4 done ( Paraxial mesoderm , Neural crest )
# element 23 5 done ( Paraxial mesoderm , Cardiomyocytes )
# element 23 6 done ( Paraxial mesoderm , Pharyngeal mesoderm )
# element 23 7 done ( Paraxial mesoderm , Nascent mesoderm )
# element 23 8 done ( Paraxial mesoderm , Haematoendothelial progenitors )
# element 23 9 done ( Paraxial mesoderm , Caudal epiblast )
# element 23 10 done ( Paraxial mesoderm , Caudal Mesoderm )
# element 23 11 done ( Paraxial mesoderm , Anterior Primitive Streak )
# element 23 12 done ( Paraxial mesoderm , Blood progenitors 1 )
# element 23 13 done ( Paraxial mesoderm , Allantois )
# element 23 14 done ( Paraxial mesoderm , PGC )
# element 23 15 done ( Paraxial mesoderm , Forebrain/Midbrain/Hindbrain )
# element 23 16 done ( Paraxial mesoderm , Mesenchyme )
# element 23 17 done ( Paraxial mesoderm , Primitive Streak )
# element 23 18 done ( Paraxial mesoderm , Parietal endoderm )
# element 23 19 done ( Paraxial mesoderm , Endothelium )
# element 23 20 done ( Paraxial mesoderm , Spinal cord )
# element 23 21 done ( Paraxial mesoderm , Erythroid3 )
# element 23 22 done ( Paraxial mesoderm , Mixed mesoderm )
# element 24 0 done ( Def. endoderm , Blood progenitors 2 )
# element 24 1 done ( Def. endoderm , Surface ectoderm )
# element 24 2 done ( Def. endoderm , Caudal neurectoderm )
# element 24 3 done ( Def. endoderm , Rostral neurectoderm )
# element 24 4 done ( Def. endoderm , Neural crest )
# element 24 5 done ( Def. endoderm , Cardiomyocytes )
# element 24 6 done ( Def. endoderm , Pharyngeal mesoderm )
# element 24 7 done ( Def. endoderm , Nascent mesoderm )
# element 24 8 done ( Def. endoderm , Haematoendothelial progenitors )
# element 24 9 done ( Def. endoderm , Caudal epiblast )
# element 24 10 done ( Def. endoderm , Caudal Mesoderm )
# element 24 11 done ( Def. endoderm , Anterior Primitive Streak )
# element 24 12 done ( Def. endoderm , Blood progenitors 1 )
# element 24 13 done ( Def. endoderm , Allantois )
# element 24 14 done ( Def. endoderm , PGC )
# element 24 15 done ( Def. endoderm , Forebrain/Midbrain/Hindbrain )
# element 24 16 done ( Def. endoderm , Mesenchyme )
# element 24 17 done ( Def. endoderm , Primitive Streak )
# element 24 18 done ( Def. endoderm , Parietal endoderm )
# element 24 19 done ( Def. endoderm , Endothelium )
# element 24 20 done ( Def. endoderm , Spinal cord )
# element 24 21 done ( Def. endoderm , Erythroid3 )
# element 24 22 done ( Def. endoderm , Mixed mesoderm )
# element 24 23 done ( Def. endoderm , Paraxial mesoderm )
# element 25 0 done ( NMP , Blood progenitors 2 )
# element 25 1 done ( NMP , Surface ectoderm )
# element 25 2 done ( NMP , Caudal neurectoderm )
# element 25 3 done ( NMP , Rostral neurectoderm )
# element 25 4 done ( NMP , Neural crest )
# element 25 5 done ( NMP , Cardiomyocytes )
# element 25 6 done ( NMP , Pharyngeal mesoderm )
# element 25 7 done ( NMP , Nascent mesoderm )
# element 25 8 done ( NMP , Haematoendothelial progenitors )
# element 25 9 done ( NMP , Caudal epiblast )
# element 25 10 done ( NMP , Caudal Mesoderm )
# element 25 11 done ( NMP , Anterior Primitive Streak )
# element 25 12 done ( NMP , Blood progenitors 1 )
# element 25 13 done ( NMP , Allantois )
# element 25 14 done ( NMP , PGC )
# element 25 15 done ( NMP , Forebrain/Midbrain/Hindbrain )
# element 25 16 done ( NMP , Mesenchyme )
# element 25 17 done ( NMP , Primitive Streak )
# element 25 18 done ( NMP , Parietal endoderm )
# element 25 19 done ( NMP , Endothelium )
# element 25 20 done ( NMP , Spinal cord )
# element 25 21 done ( NMP , Erythroid3 )
# element 25 22 done ( NMP , Mixed mesoderm )
# element 25 23 done ( NMP , Paraxial mesoderm )
# element 25 24 done ( NMP , Def. endoderm )
# element 26 0 done ( Epiblast , Blood progenitors 2 )
# element 26 1 done ( Epiblast , Surface ectoderm )
# element 26 2 done ( Epiblast , Caudal neurectoderm )
# element 26 3 done ( Epiblast , Rostral neurectoderm )
# element 26 4 done ( Epiblast , Neural crest )
# element 26 5 done ( Epiblast , Cardiomyocytes )
# element 26 6 done ( Epiblast , Pharyngeal mesoderm )
# element 26 7 done ( Epiblast , Nascent mesoderm )
# element 26 8 done ( Epiblast , Haematoendothelial progenitors )
# element 26 9 done ( Epiblast , Caudal epiblast )
# element 26 10 done ( Epiblast , Caudal Mesoderm )
# element 26 11 done ( Epiblast , Anterior Primitive Streak )
# element 26 12 done ( Epiblast , Blood progenitors 1 )
# element 26 13 done ( Epiblast , Allantois )
# element 26 14 done ( Epiblast , PGC )
# element 26 15 done ( Epiblast , Forebrain/Midbrain/Hindbrain )
# element 26 16 done ( Epiblast , Mesenchyme )
# element 26 17 done ( Epiblast , Primitive Streak )
# element 26 18 done ( Epiblast , Parietal endoderm )
# element 26 19 done ( Epiblast , Endothelium )
# element 26 20 done ( Epiblast , Spinal cord )
# element 26 21 done ( Epiblast , Erythroid3 )
# element 26 22 done ( Epiblast , Mixed mesoderm )
# element 26 23 done ( Epiblast , Paraxial mesoderm )
# element 26 24 done ( Epiblast , Def. endoderm )
# element 26 25 done ( Epiblast , NMP )
# element 27 0 done ( Erythroid1 , Blood progenitors 2 )
# element 27 1 done ( Erythroid1 , Surface ectoderm )
# element 27 2 done ( Erythroid1 , Caudal neurectoderm )
# element 27 3 done ( Erythroid1 , Rostral neurectoderm )
# element 27 4 done ( Erythroid1 , Neural crest )
# element 27 5 done ( Erythroid1 , Cardiomyocytes )
# element 27 6 done ( Erythroid1 , Pharyngeal mesoderm )
# element 27 7 done ( Erythroid1 , Nascent mesoderm )
# element 27 8 done ( Erythroid1 , Haematoendothelial progenitors )
# element 27 9 done ( Erythroid1 , Caudal epiblast )
# element 27 10 done ( Erythroid1 , Caudal Mesoderm )
# element 27 11 done ( Erythroid1 , Anterior Primitive Streak )
# element 27 12 done ( Erythroid1 , Blood progenitors 1 )
# element 27 13 done ( Erythroid1 , Allantois )
# element 27 14 done ( Erythroid1 , PGC )
# element 27 15 done ( Erythroid1 , Forebrain/Midbrain/Hindbrain )
# element 27 16 done ( Erythroid1 , Mesenchyme )
# element 27 17 done ( Erythroid1 , Primitive Streak )
# element 27 18 done ( Erythroid1 , Parietal endoderm )
# element 27 19 done ( Erythroid1 , Endothelium )
# element 27 20 done ( Erythroid1 , Spinal cord )
# element 27 21 done ( Erythroid1 , Erythroid3 )
# element 27 22 done ( Erythroid1 , Mixed mesoderm )
# element 27 23 done ( Erythroid1 , Paraxial mesoderm )
# element 27 24 done ( Erythroid1 , Def. endoderm )
# element 27 25 done ( Erythroid1 , NMP )
# element 27 26 done ( Erythroid1 , Epiblast )
# element 28 0 done ( Visceral endoderm , Blood progenitors 2 )
# element 28 1 done ( Visceral endoderm , Surface ectoderm )
# element 28 2 done ( Visceral endoderm , Caudal neurectoderm )
# element 28 3 done ( Visceral endoderm , Rostral neurectoderm )
# element 28 4 done ( Visceral endoderm , Neural crest )
# element 28 5 done ( Visceral endoderm , Cardiomyocytes )
# element 28 6 done ( Visceral endoderm , Pharyngeal mesoderm )
# element 28 7 done ( Visceral endoderm , Nascent mesoderm )
# element 28 8 done ( Visceral endoderm , Haematoendothelial progenitors )
# element 28 9 done ( Visceral endoderm , Caudal epiblast )
# element 28 10 done ( Visceral endoderm , Caudal Mesoderm )
# element 28 11 done ( Visceral endoderm , Anterior Primitive Streak )
# element 28 12 done ( Visceral endoderm , Blood progenitors 1 )
# element 28 13 done ( Visceral endoderm , Allantois )
# element 28 14 done ( Visceral endoderm , PGC )
# element 28 15 done ( Visceral endoderm , Forebrain/Midbrain/Hindbrain )
# element 28 16 done ( Visceral endoderm , Mesenchyme )
# element 28 17 done ( Visceral endoderm , Primitive Streak )
# element 28 18 done ( Visceral endoderm , Parietal endoderm )
# element 28 19 done ( Visceral endoderm , Endothelium )
# element 28 20 done ( Visceral endoderm , Spinal cord )
# element 28 21 done ( Visceral endoderm , Erythroid3 )
# element 28 22 done ( Visceral endoderm , Mixed mesoderm )
# element 28 23 done ( Visceral endoderm , Paraxial mesoderm )
# element 28 24 done ( Visceral endoderm , Def. endoderm )
# element 28 25 done ( Visceral endoderm , NMP )
# element 28 26 done ( Visceral endoderm , Epiblast )
# element 28 27 done ( Visceral endoderm , Erythroid1 )
# element 29 0 done ( Gut , Blood progenitors 2 )
# element 29 1 done ( Gut , Surface ectoderm )
# element 29 2 done ( Gut , Caudal neurectoderm )
# element 29 3 done ( Gut , Rostral neurectoderm )
# element 29 4 done ( Gut , Neural crest )
# element 29 5 done ( Gut , Cardiomyocytes )
# element 29 6 done ( Gut , Pharyngeal mesoderm )
# element 29 7 done ( Gut , Nascent mesoderm )
# element 29 8 done ( Gut , Haematoendothelial progenitors )
# element 29 9 done ( Gut , Caudal epiblast )
# element 29 10 done ( Gut , Caudal Mesoderm )
# element 29 11 done ( Gut , Anterior Primitive Streak )
# element 29 12 done ( Gut , Blood progenitors 1 )
# element 29 13 done ( Gut , Allantois )
# element 29 14 done ( Gut , PGC )
# element 29 15 done ( Gut , Forebrain/Midbrain/Hindbrain )
# element 29 16 done ( Gut , Mesenchyme )
# element 29 17 done ( Gut , Primitive Streak )
# element 29 18 done ( Gut , Parietal endoderm )
# element 29 19 done ( Gut , Endothelium )
# element 29 20 done ( Gut , Spinal cord )
# element 29 21 done ( Gut , Erythroid3 )
# element 29 22 done ( Gut , Mixed mesoderm )
# element 29 23 done ( Gut , Paraxial mesoderm )
# element 29 24 done ( Gut , Def. endoderm )
# element 29 25 done ( Gut , NMP )
# element 29 26 done ( Gut , Epiblast )
# element 29 27 done ( Gut , Erythroid1 )
# element 29 28 done ( Gut , Visceral endoderm )
# element 30 0 done ( Notochord , Blood progenitors 2 )
# element 30 1 done ( Notochord , Surface ectoderm )
# element 30 2 done ( Notochord , Caudal neurectoderm )
# element 30 3 done ( Notochord , Rostral neurectoderm )
# element 30 4 done ( Notochord , Neural crest )
# element 30 5 done ( Notochord , Cardiomyocytes )
# element 30 6 done ( Notochord , Pharyngeal mesoderm )
# element 30 7 done ( Notochord , Nascent mesoderm )
# element 30 8 done ( Notochord , Haematoendothelial progenitors )
# element 30 9 done ( Notochord , Caudal epiblast )
# element 30 10 done ( Notochord , Caudal Mesoderm )
# element 30 11 done ( Notochord , Anterior Primitive Streak )
# element 30 12 done ( Notochord , Blood progenitors 1 )
# element 30 13 done ( Notochord , Allantois )
# element 30 14 done ( Notochord , PGC )
# element 30 15 done ( Notochord , Forebrain/Midbrain/Hindbrain )
# element 30 16 done ( Notochord , Mesenchyme )
# element 30 17 done ( Notochord , Primitive Streak )
# element 30 18 done ( Notochord , Parietal endoderm )
# element 30 19 done ( Notochord , Endothelium )
# element 30 20 done ( Notochord , Spinal cord )
# element 30 21 done ( Notochord , Erythroid3 )
# element 30 22 done ( Notochord , Mixed mesoderm )
# element 30 23 done ( Notochord , Paraxial mesoderm )
# element 30 24 done ( Notochord , Def. endoderm )
# element 30 25 done ( Notochord , NMP )
# element 30 26 done ( Notochord , Epiblast )
# element 30 27 done ( Notochord , Erythroid1 )
# element 30 28 done ( Notochord , Visceral endoderm )
# element 30 29 done ( Notochord , Gut )
# element 31 0 done ( Erythroid2 , Blood progenitors 2 )
# element 31 1 done ( Erythroid2 , Surface ectoderm )
# element 31 2 done ( Erythroid2 , Caudal neurectoderm )
# element 31 3 done ( Erythroid2 , Rostral neurectoderm )
# element 31 4 done ( Erythroid2 , Neural crest )
# element 31 5 done ( Erythroid2 , Cardiomyocytes )
# element 31 6 done ( Erythroid2 , Pharyngeal mesoderm )
# element 31 7 done ( Erythroid2 , Nascent mesoderm )
# element 31 8 done ( Erythroid2 , Haematoendothelial progenitors )
# element 31 9 done ( Erythroid2 , Caudal epiblast )
# element 31 10 done ( Erythroid2 , Caudal Mesoderm )
# element 31 11 done ( Erythroid2 , Anterior Primitive Streak )
# element 31 12 done ( Erythroid2 , Blood progenitors 1 )
# element 31 13 done ( Erythroid2 , Allantois )
# element 31 14 done ( Erythroid2 , PGC )
# element 31 15 done ( Erythroid2 , Forebrain/Midbrain/Hindbrain )
# element 31 16 done ( Erythroid2 , Mesenchyme )
# element 31 17 done ( Erythroid2 , Primitive Streak )
# element 31 18 done ( Erythroid2 , Parietal endoderm )
# element 31 19 done ( Erythroid2 , Endothelium )
# element 31 20 done ( Erythroid2 , Spinal cord )
# element 31 21 done ( Erythroid2 , Erythroid3 )
# element 31 22 done ( Erythroid2 , Mixed mesoderm )
# element 31 23 done ( Erythroid2 , Paraxial mesoderm )
# element 31 24 done ( Erythroid2 , Def. endoderm )
# element 31 25 done ( Erythroid2 , NMP )
# element 31 26 done ( Erythroid2 , Epiblast )
# element 31 27 done ( Erythroid2 , Erythroid1 )
# element 31 28 done ( Erythroid2 , Visceral endoderm )
# element 31 29 done ( Erythroid2 , Gut )
# element 31 30 done ( Erythroid2 , Notochord )
# element 32 0 done ( Intermediate mesoderm , Blood progenitors 2 )
# element 32 1 done ( Intermediate mesoderm , Surface ectoderm )
# element 32 2 done ( Intermediate mesoderm , Caudal neurectoderm )
# element 32 3 done ( Intermediate mesoderm , Rostral neurectoderm )
# element 32 4 done ( Intermediate mesoderm , Neural crest )
# element 32 5 done ( Intermediate mesoderm , Cardiomyocytes )
# element 32 6 done ( Intermediate mesoderm , Pharyngeal mesoderm )
# element 32 7 done ( Intermediate mesoderm , Nascent mesoderm )
# element 32 8 done ( Intermediate mesoderm , Haematoendothelial progenitors )
# element 32 9 done ( Intermediate mesoderm , Caudal epiblast )
# element 32 10 done ( Intermediate mesoderm , Caudal Mesoderm )
# element 32 11 done ( Intermediate mesoderm , Anterior Primitive Streak )
# element 32 12 done ( Intermediate mesoderm , Blood progenitors 1 )
# element 32 13 done ( Intermediate mesoderm , Allantois )
# element 32 14 done ( Intermediate mesoderm , PGC )
# element 32 15 done ( Intermediate mesoderm , Forebrain/Midbrain/Hindbrain )
# element 32 16 done ( Intermediate mesoderm , Mesenchyme )
# element 32 17 done ( Intermediate mesoderm , Primitive Streak )
# element 32 18 done ( Intermediate mesoderm , Parietal endoderm )
# element 32 19 done ( Intermediate mesoderm , Endothelium )
# element 32 20 done ( Intermediate mesoderm , Spinal cord )
# element 32 21 done ( Intermediate mesoderm , Erythroid3 )
# element 32 22 done ( Intermediate mesoderm , Mixed mesoderm )
# element 32 23 done ( Intermediate mesoderm , Paraxial mesoderm )
# element 32 24 done ( Intermediate mesoderm , Def. endoderm )
# element 32 25 done ( Intermediate mesoderm , NMP )
# element 32 26 done ( Intermediate mesoderm , Epiblast )
# element 32 27 done ( Intermediate mesoderm , Erythroid1 )
# element 32 28 done ( Intermediate mesoderm , Visceral endoderm )
# element 32 29 done ( Intermediate mesoderm , Gut )
# element 32 30 done ( Intermediate mesoderm , Notochord )
# element 32 31 done ( Intermediate mesoderm , Erythroid2 )
# element 33 0 done ( Somitic mesoderm , Blood progenitors 2 )
# element 33 1 done ( Somitic mesoderm , Surface ectoderm )
# element 33 2 done ( Somitic mesoderm , Caudal neurectoderm )
# element 33 3 done ( Somitic mesoderm , Rostral neurectoderm )
# element 33 4 done ( Somitic mesoderm , Neural crest )
# element 33 5 done ( Somitic mesoderm , Cardiomyocytes )
# element 33 6 done ( Somitic mesoderm , Pharyngeal mesoderm )
# element 33 7 done ( Somitic mesoderm , Nascent mesoderm )
# element 33 8 done ( Somitic mesoderm , Haematoendothelial progenitors )
# element 33 9 done ( Somitic mesoderm , Caudal epiblast )
# element 33 10 done ( Somitic mesoderm , Caudal Mesoderm )
# element 33 11 done ( Somitic mesoderm , Anterior Primitive Streak )
# element 33 12 done ( Somitic mesoderm , Blood progenitors 1 )
# element 33 13 done ( Somitic mesoderm , Allantois )
# element 33 14 done ( Somitic mesoderm , PGC )
# element 33 15 done ( Somitic mesoderm , Forebrain/Midbrain/Hindbrain )
# element 33 16 done ( Somitic mesoderm , Mesenchyme )
# element 33 17 done ( Somitic mesoderm , Primitive Streak )
# element 33 18 done ( Somitic mesoderm , Parietal endoderm )
# element 33 19 done ( Somitic mesoderm , Endothelium )
# element 33 20 done ( Somitic mesoderm , Spinal cord )
# element 33 21 done ( Somitic mesoderm , Erythroid3 )
# element 33 22 done ( Somitic mesoderm , Mixed mesoderm )
# element 33 23 done ( Somitic mesoderm , Paraxial mesoderm )
# element 33 24 done ( Somitic mesoderm , Def. endoderm )
# element 33 25 done ( Somitic mesoderm , NMP )
# element 33 26 done ( Somitic mesoderm , Epiblast )
# element 33 27 done ( Somitic mesoderm , Erythroid1 )
# element 33 28 done ( Somitic mesoderm , Visceral endoderm )
# element 33 29 done ( Somitic mesoderm , Gut )
# element 33 30 done ( Somitic mesoderm , Notochord )
# element 33 31 done ( Somitic mesoderm , Erythroid2 )
# element 33 32 done ( Somitic mesoderm , Intermediate mesoderm )
# saved cosine matrix to  mouse_cosine_dist_matrix_DE_subset0.8.csv
# CPU times: user 1min 57s, sys: 53.3 s, total: 2min 51s
# Wall time: 2min 50s
# 0

# %%
# trying out 100 times for mouse, cosine
# this took 5-6 hours
for i in range(100):
    print('creating distance matrix number',i+1)
    sc_to_dist_subset('celltype',['cosine'],'mouse'+str(i+1),filepath_h5ad='/home/jovyan/notebooks/Tree_of_Cells/Mouse_devo.h5ad')
# Out:
# creating distance matrix number 1
# adata object created, expression matrix dimensions: (9227, 29452)
# ranking genes
#     finished (0:01:05.06) --> added to `.uns['rank_genes_groups']`
#     'names', sorted np.recarray to be indexed by group ids
#     'scores', sorted np.recarray to be indexed by group ids
#     'logfoldchanges', sorted np.recarray to be indexed by group ids
#     'pvals', sorted np.recarray to be indexed by group ids
#     'pvals_adj', sorted np.recarray to be indexed by group ids
# randomly selecting a proportion (alpha) of genes
# list of  80 % of all DE genes ( 1153  ) created, of total initial 29452 genes
# a snippet of DE_genes subset: ['ENSMUSG00000024308', 'ENSMUSG00000089804', 'ENSMUSG00000031633', 'ENSMUSG00000038235', 'ENSMUSG00000021613']
# adata object subsetted to DE genes only, dimensions: (9227, 922)
# 34 cell types: ['Blood progenitors 2', 'Surface ectoderm', 'Caudal neurectoderm', 'Rostral neurectoderm', 'Neural crest', 'Cardiomyocytes', 'Pharyngeal mesoderm', 'Nascent mesoderm', 'Haematoendothelial progenitors', 'Caudal epiblast', 'Caudal Mesoderm', 'Anterior Primitive Streak', 'Blood progenitors 1', 'Allantois', 'PGC', 'Forebrain/Midbrain/Hindbrain', 'Mesenchyme', 'Primitive Streak', 'Parietal endoderm', 'Endothelium', 'Spinal cord', 'Erythroid3', 'Mixed mesoderm', 'Paraxial mesoderm', 'Def. endoderm', 'NMP', 'Epiblast', 'Erythroid1', 'Visceral endoderm', 'Gut', 'Notochord', 'Erythroid2', 'Intermediate mesoderm', 'Somitic mesoderm']
# creating cosine similarity distance matrix
# element 1 0 done ( Surface ectoderm , Blood progenitors 2 )
# element 2 0 done ( Caudal neurectoderm , Blood progenitors 2 )
# element 2 1 done ( Caudal neurectoderm , Surface ectoderm )
# element 3 0 done ( Rostral neurectoderm , Blood progenitors 2 )
# element 3 1 done ( Rostral neurectoderm , Surface ectoderm )
# element 3 2 done ( Rostral neurectoderm , Caudal neurectoderm )
# element 4 0 done ( Neural crest , Blood progenitors 2 )
# element 4 1 done ( Neural crest , Surface ectoderm )
# element 4 2 done ( Neural crest , Caudal neurectoderm )
# element 4 3 done ( Neural crest , Rostral neurectoderm )
# element 5 0 done ( Cardiomyocytes , Blood progenitors 2 )
# element 5 1 done ( Cardiomyocytes , Surface ectoderm )
# element 5 2 done ( Cardiomyocytes , Caudal neurectoderm )
# element 5 3 done ( Cardiomyocytes , Rostral neurectoderm )
# element 5 4 done ( Cardiomyocytes , Neural crest )
# element 6 0 done ( Pharyngeal mesoderm , Blood progenitors 2 )
# element 6 1 done ( Pharyngeal mesoderm , Surface ectoderm )
# element 6 2 done ( Pharyngeal mesoderm , Caudal neurectoderm )
# element 6 3 done ( Pharyngeal mesoderm , Rostral neurectoderm )
# element 6 4 done ( Pharyngeal mesoderm , Neural crest )
# element 6 5 done ( Pharyngeal mesoderm , Cardiomyocytes )
# element 7 0 done ( Nascent mesoderm , Blood progenitors 2 )
# element 7 1 done ( Nascent mesoderm , Surface ectoderm )
# element 7 2 done ( Nascent mesoderm , Caudal neurectoderm )
# element 7 3 done ( Nascent mesoderm , Rostral neurectoderm )
# element 7 4 done ( Nascent mesoderm , Neural crest )
# element 7 5 done ( Nascent mesoderm , Cardiomyocytes )
# element 7 6 done ( Nascent mesoderm , Pharyngeal mesoderm )
# element 8 0 done ( Haematoendothelial progenitors , Blood progenitors 2 )
# element 8 1 done ( Haematoendothelial progenitors , Surface ectoderm )
# element 8 2 done ( Haematoendothelial progenitors , Caudal neurectoderm )
# element 8 3 done ( Haematoendothelial progenitors , Rostral neurectoderm )
# element 8 4 done ( Haematoendothelial progenitors , Neural crest )
# element 8 5 done ( Haematoendothelial progenitors , Cardiomyocytes )
# element 8 6 done ( Haematoendothelial progenitors , Pharyngeal mesoderm )
# element 8 7 done ( Haematoendothelial progenitors , Nascent mesoderm )
# element 9 0 done ( Caudal epiblast , Blood progenitors 2 )
# element 9 1 done ( Caudal epiblast , Surface ectoderm )
# element 9 2 done ( Caudal epiblast , Caudal neurectoderm )
# element 9 3 done ( Caudal epiblast , Rostral neurectoderm )
# element 9 4 done ( Caudal epiblast , Neural crest )
# element 9 5 done ( Caudal epiblast , Cardiomyocytes )
# element 9 6 done ( Caudal epiblast , Pharyngeal mesoderm )
# element 9 7 done ( Caudal epiblast , Nascent mesoderm )
# element 9 8 done ( Caudal epiblast , Haematoendothelial progenitors )
# element 10 0 done ( Caudal Mesoderm , Blood progenitors 2 )
# element 10 1 done ( Caudal Mesoderm , Surface ectoderm )
# element 10 2 done ( Caudal Mesoderm , Caudal neurectoderm )
# element 10 3 done ( Caudal Mesoderm , Rostral neurectoderm )
# element 10 4 done ( Caudal Mesoderm , Neural crest )
# element 10 5 done ( Caudal Mesoderm , Cardiomyocytes )
# element 10 6 done ( Caudal Mesoderm , Pharyngeal mesoderm )
# element 10 7 done ( Caudal Mesoderm , Nascent mesoderm )
# element 10 8 done ( Caudal Mesoderm , Haematoendothelial progenitors )
# element 10 9 done ( Caudal Mesoderm , Caudal epiblast )
# element 11 0 done ( Anterior Primitive Streak , Blood progenitors 2 )
# element 11 1 done ( Anterior Primitive Streak , Surface ectoderm )
# element 11 2 done ( Anterior Primitive Streak , Caudal neurectoderm )
# element 11 3 done ( Anterior Primitive Streak , Rostral neurectoderm )
# element 11 4 done ( Anterior Primitive Streak , Neural crest )
# element 11 5 done ( Anterior Primitive Streak , Cardiomyocytes )
# element 11 6 done ( Anterior Primitive Streak , Pharyngeal mesoderm )
# element 11 7 done ( Anterior Primitive Streak , Nascent mesoderm )
# element 11 8 done ( Anterior Primitive Streak , Haematoendothelial progenitors )
# element 11 9 done ( Anterior Primitive Streak , Caudal epiblast )
# element 11 10 done ( Anterior Primitive Streak , Caudal Mesoderm )
# element 12 0 done ( Blood progenitors 1 , Blood progenitors 2 )
# element 12 1 done ( Blood progenitors 1 , Surface ectoderm )
# element 12 2 done ( Blood progenitors 1 , Caudal neurectoderm )
# element 12 3 done ( Blood progenitors 1 , Rostral neurectoderm )
# element 12 4 done ( Blood progenitors 1 , Neural crest )
# element 12 5 done ( Blood progenitors 1 , Cardiomyocytes )
# element 12 6 done ( Blood progenitors 1 , Pharyngeal mesoderm )
# element 12 7 done ( Blood progenitors 1 , Nascent mesoderm )
# element 12 8 done ( Blood progenitors 1 , Haematoendothelial progenitors )
# element 12 9 done ( Blood progenitors 1 , Caudal epiblast )
# element 12 10 done ( Blood progenitors 1 , Caudal Mesoderm )
# element 12 11 done ( Blood progenitors 1 , Anterior Primitive Streak )
# element 13 0 done ( Allantois , Blood progenitors 2 )
# element 13 1 done ( Allantois , Surface ectoderm )
# element 13 2 done ( Allantois , Caudal neurectoderm )
# element 13 3 done ( Allantois , Rostral neurectoderm )
# element 13 4 done ( Allantois , Neural crest )
# element 13 5 done ( Allantois , Cardiomyocytes )
# element 13 6 done ( Allantois , Pharyngeal mesoderm )
# element 13 7 done ( Allantois , Nascent mesoderm )
# element 13 8 done ( Allantois , Haematoendothelial progenitors )
# element 13 9 done ( Allantois , Caudal epiblast )
# element 13 10 done ( Allantois , Caudal Mesoderm )
# element 13 11 done ( Allantois , Anterior Primitive Streak )
# element 13 12 done ( Allantois , Blood progenitors 1 )
# element 14 0 done ( PGC , Blood progenitors 2 )
# element 14 1 done ( PGC , Surface ectoderm )
# element 14 2 done ( PGC , Caudal neurectoderm )
# element 14 3 done ( PGC , Rostral neurectoderm )
# element 14 4 done ( PGC , Neural crest )
# element 14 5 done ( PGC , Cardiomyocytes )
# element 14 6 done ( PGC , Pharyngeal mesoderm )
# element 14 7 done ( PGC , Nascent mesoderm )
# element 14 8 done ( PGC , Haematoendothelial progenitors )
# element 14 9 done ( PGC , Caudal epiblast )
# element 14 10 done ( PGC , Caudal Mesoderm )
# element 14 11 done ( PGC , Anterior Primitive Streak )
# element 14 12 done ( PGC , Blood progenitors 1 )
# element 14 13 done ( PGC , Allantois )
# element 15 0 done ( Forebrain/Midbrain/Hindbrain , Blood progenitors 2 )
# element 15 1 done ( Forebrain/Midbrain/Hindbrain , Surface ectoderm )
# element 15 2 done ( Forebrain/Midbrain/Hindbrain , Caudal neurectoderm )
# element 15 3 done ( Forebrain/Midbrain/Hindbrain , Rostral neurectoderm )
# element 15 4 done ( Forebrain/Midbrain/Hindbrain , Neural crest )
# element 15 5 done ( Forebrain/Midbrain/Hindbrain , Cardiomyocytes )
# element 15 6 done ( Forebrain/Midbrain/Hindbrain , Pharyngeal mesoderm )
# element 15 7 done ( Forebrain/Midbrain/Hindbrain , Nascent mesoderm )
# element 15 8 done ( Forebrain/Midbrain/Hindbrain , Haematoendothelial progenitors )
# element 15 9 done ( Forebrain/Midbrain/Hindbrain , Caudal epiblast )
# element 15 10 done ( Forebrain/Midbrain/Hindbrain , Caudal Mesoderm )
# element 15 11 done ( Forebrain/Midbrain/Hindbrain , Anterior Primitive Streak )
# element 15 12 done ( Forebrain/Midbrain/Hindbrain , Blood progenitors 1 )
# element 15 13 done ( Forebrain/Midbrain/Hindbrain , Allantois )
# element 15 14 done ( Forebrain/Midbrain/Hindbrain , PGC )
# element 16 0 done ( Mesenchyme , Blood progenitors 2 )
# element 16 1 done ( Mesenchyme , Surface ectoderm )
# element 16 2 done ( Mesenchyme , Caudal neurectoderm )
# element 16 3 done ( Mesenchyme , Rostral neurectoderm )
# element 16 4 done ( Mesenchyme , Neural crest )
# element 16 5 done ( Mesenchyme , Cardiomyocytes )
# element 16 6 done ( Mesenchyme , Pharyngeal mesoderm )
# element 16 7 done ( Mesenchyme , Nascent mesoderm )
# element 16 8 done ( Mesenchyme , Haematoendothelial progenitors )
# element 16 9 done ( Mesenchyme , Caudal epiblast )
# element 16 10 done ( Mesenchyme , Caudal Mesoderm )
# element 16 11 done ( Mesenchyme , Anterior Primitive Streak )
# element 16 12 done ( Mesenchyme , Blood progenitors 1 )
# element 16 13 done ( Mesenchyme , Allantois )
# element 16 14 done ( Mesenchyme , PGC )
# element 16 15 done ( Mesenchyme , Forebrain/Midbrain/Hindbrain )
# element 17 0 done ( Primitive Streak , Blood progenitors 2 )
# element 17 1 done ( Primitive Streak , Surface ectoderm )
# element 17 2 done ( Primitive Streak , Caudal neurectoderm )
# element 17 3 done ( Primitive Streak , Rostral neurectoderm )
# element 17 4 done ( Primitive Streak , Neural crest )
# element 17 5 done ( Primitive Streak , Cardiomyocytes )
# element 17 6 done ( Primitive Streak , Pharyngeal mesoderm )
# element 17 7 done ( Primitive Streak , Nascent mesoderm )
# element 17 8 done ( Primitive Streak , Haematoendothelial progenitors )
# element 17 9 done ( Primitive Streak , Caudal epiblast )
# element 17 10 done ( Primitive Streak , Caudal Mesoderm )
# element 17 11 done ( Primitive Streak , Anterior Primitive Streak )
# element 17 12 done ( Primitive Streak , Blood progenitors 1 )
# element 17 13 done ( Primitive Streak , Allantois )
# element 17 14 done ( Primitive Streak , PGC )
# element 17 15 done ( Primitive Streak , Forebrain/Midbrain/Hindbrain )
# element 17 16 done ( Primitive Streak , Mesenchyme )
# element 18 0 done ( Parietal endoderm , Blood progenitors 2 )
# element 18 1 done ( Parietal endoderm , Surface ectoderm )
# element 18 2 done ( Parietal endoderm , Caudal neurectoderm )
# element 18 3 done ( Parietal endoderm , Rostral neurectoderm )
# element 18 4 done ( Parietal endoderm , Neural crest )
# element 18 5 done ( Parietal endoderm , Cardiomyocytes )
# element 18 6 done ( Parietal endoderm , Pharyngeal mesoderm )
# element 18 7 done ( Parietal endoderm , Nascent mesoderm )
# element 18 8 done ( Parietal endoderm , Haematoendothelial progenitors )
# element 18 9 done ( Parietal endoderm , Caudal epiblast )
# element 18 10 done ( Parietal endoderm , Caudal Mesoderm )
# element 18 11 done ( Parietal endoderm , Anterior Primitive Streak )
# element 18 12 done ( Parietal endoderm , Blood progenitors 1 )
# element 18 13 done ( Parietal endoderm , Allantois )
# element 18 14 done ( Parietal endoderm , PGC )
# element 18 15 done ( Parietal endoderm , Forebrain/Midbrain/Hindbrain )
# element 18 16 done ( Parietal endoderm , Mesenchyme )
# element 18 17 done ( Parietal endoderm , Primitive Streak )
# element 19 0 done ( Endothelium , Blood progenitors 2 )
# element 19 1 done ( Endothelium , Surface ectoderm )
# element 19 2 done ( Endothelium , Caudal neurectoderm )
# element 19 3 done ( Endothelium , Rostral neurectoderm )
# element 19 4 done ( Endothelium , Neural crest )
# element 19 5 done ( Endothelium , Cardiomyocytes )
# element 19 6 done ( Endothelium , Pharyngeal mesoderm )
# element 19 7 done ( Endothelium , Nascent mesoderm )
# element 19 8 done ( Endothelium , Haematoendothelial progenitors )
# element 19 9 done ( Endothelium , Caudal epiblast )
# element 19 10 done ( Endothelium , Caudal Mesoderm )
# element 19 11 done ( Endothelium , Anterior Primitive Streak )
# element 19 12 done ( Endothelium , Blood progenitors 1 )
# element 19 13 done ( Endothelium , Allantois )
# element 19 14 done ( Endothelium , PGC )
# element 19 15 done ( Endothelium , Forebrain/Midbrain/Hindbrain )
# element 19 16 done ( Endothelium , Mesenchyme )
# element 19 17 done ( Endothelium , Primitive Streak )
# element 19 18 done ( Endothelium , Parietal endoderm )
# element 20 0 done ( Spinal cord , Blood progenitors 2 )
# element 20 1 done ( Spinal cord , Surface ectoderm )
# element 20 2 done ( Spinal cord , Caudal neurectoderm )
# element 20 3 done ( Spinal cord , Rostral neurectoderm )
# element 20 4 done ( Spinal cord , Neural crest )
# element 20 5 done ( Spinal cord , Cardiomyocytes )
# element 20 6 done ( Spinal cord , Pharyngeal mesoderm )
# element 20 7 done ( Spinal cord , Nascent mesoderm )
# element 20 8 done ( Spinal cord , Haematoendothelial progenitors )
# element 20 9 done ( Spinal cord , Caudal epiblast )
# element 20 10 done ( Spinal cord , Caudal Mesoderm )
# element 20 11 done ( Spinal cord , Anterior Primitive Streak )
# element 20 12 done ( Spinal cord , Blood progenitors 1 )
# element 20 13 done ( Spinal cord , Allantois )
# element 20 14 done ( Spinal cord , PGC )
# element 20 15 done ( Spinal cord , Forebrain/Midbrain/Hindbrain )
# element 20 16 done ( Spinal cord , Mesenchyme )
# element 20 17 done ( Spinal cord , Primitive Streak )
# element 20 18 done ( Spinal cord , Parietal endoderm )
# element 20 19 done ( Spinal cord , Endothelium )
# element 21 0 done ( Erythroid3 , Blood progenitors 2 )
# element 21 1 done ( Erythroid3 , Surface ectoderm )
# element 21 2 done ( Erythroid3 , Caudal neurectoderm )
# element 21 3 done ( Erythroid3 , Rostral neurectoderm )
# element 21 4 done ( Erythroid3 , Neural crest )
# element 21 5 done ( Erythroid3 , Cardiomyocytes )
# element 21 6 done ( Erythroid3 , Pharyngeal mesoderm )
# element 21 7 done ( Erythroid3 , Nascent mesoderm )
# element 21 8 done ( Erythroid3 , Haematoendothelial progenitors )
# element 21 9 done ( Erythroid3 , Caudal epiblast )
# element 21 10 done ( Erythroid3 , Caudal Mesoderm )
# element 21 11 done ( Erythroid3 , Anterior Primitive Streak )
# element 21 12 done ( Erythroid3 , Blood progenitors 1 )
# element 21 13 done ( Erythroid3 , Allantois )
# element 21 14 done ( Erythroid3 , PGC )
# element 21 15 done ( Erythroid3 , Forebrain/Midbrain/Hindbrain )
# element 21 16 done ( Erythroid3 , Mesenchyme )
# element 21 17 done ( Erythroid3 , Primitive Streak )
# element 21 18 done ( Erythroid3 , Parietal endoderm )
# element 21 19 done ( Erythroid3 , Endothelium )
# element 21 20 done ( Erythroid3 , Spinal cord )
# element 22 0 done ( Mixed mesoderm , Blood progenitors 2 )
# element 22 1 done ( Mixed mesoderm , Surface ectoderm )
# element 22 2 done ( Mixed mesoderm , Caudal neurectoderm )
# element 22 3 done ( Mixed mesoderm , Rostral neurectoderm )
# element 22 4 done ( Mixed mesoderm , Neural crest )
# element 22 5 done ( Mixed mesoderm , Cardiomyocytes )
# element 22 6 done ( Mixed mesoderm , Pharyngeal mesoderm )
# element 22 7 done ( Mixed mesoderm , Nascent mesoderm )
# element 22 8 done ( Mixed mesoderm , Haematoendothelial progenitors )
# element 22 9 done ( Mixed mesoderm , Caudal epiblast )
# element 22 10 done ( Mixed mesoderm , Caudal Mesoderm )
# element 22 11 done ( Mixed mesoderm , Anterior Primitive Streak )
# element 22 12 done ( Mixed mesoderm , Blood progenitors 1 )
# element 22 13 done ( Mixed mesoderm , Allantois )
# element 22 14 done ( Mixed mesoderm , PGC )
# element 22 15 done ( Mixed mesoderm , Forebrain/Midbrain/Hindbrain )
# element 22 16 done ( Mixed mesoderm , Mesenchyme )
# element 22 17 done ( Mixed mesoderm , Primitive Streak )
# element 22 18 done ( Mixed mesoderm , Parietal endoderm )
# element 22 19 done ( Mixed mesoderm , Endothelium )
# element 22 20 done ( Mixed mesoderm , Spinal cord )
# element 22 21 done ( Mixed mesoderm , Erythroid3 )
# element 23 0 done ( Paraxial mesoderm , Blood progenitors 2 )
# element 23 1 done ( Paraxial mesoderm , Surface ectoderm )
# element 23 2 done ( Paraxial mesoderm , Caudal neurectoderm )
# element 23 3 done ( Paraxial mesoderm , Rostral neurectoderm )
# element 23 4 done ( Paraxial mesoderm , Neural crest )
# element 23 5 done ( Paraxial mesoderm , Cardiomyocytes )
# element 23 6 done ( Paraxial mesoderm , Pharyngeal mesoderm )
# element 23 7 done ( Paraxial mesoderm , Nascent mesoderm )
# element 23 8 done ( Paraxial mesoderm , Haematoendothelial progenitors )
# element 23 9 done ( Paraxial mesoderm , Caudal epiblast )
# element 23 10 done ( Paraxial mesoderm , Caudal Mesoderm )
# element 23 11 done ( Paraxial mesoderm , Anterior Primitive Streak )
# element 23 12 done ( Paraxial mesoderm , Blood progenitors 1 )
# element 23 13 done ( Paraxial mesoderm , Allantois )
# element 23 14 done ( Paraxial mesoderm , PGC )
# element 23 15 done ( Paraxial mesoderm , Forebrain/Midbrain/Hindbrain )
# element 23 16 done ( Paraxial mesoderm , Mesenchyme )
# element 23 17 done ( Paraxial mesoderm , Primitive Streak )
# element 23 18 done ( Paraxial mesoderm , Parietal endoderm )
# element 23 19 done ( Paraxial mesoderm , Endothelium )
# element 23 20 done ( Paraxial mesoderm , Spinal cord )
# element 23 21 done ( Paraxial mesoderm , Erythroid3 )
# element 23 22 done ( Paraxial mesoderm , Mixed mesoderm )
# element 24 0 done ( Def. endoderm , Blood progenitors 2 )
# element 24 1 done ( Def. endoderm , Surface ectoderm )
# element 24 2 done ( Def. endoderm , Caudal neurectoderm )
# element 24 3 done ( Def. endoderm , Rostral neurectoderm )
# element 24 4 done ( Def. endoderm , Neural crest )
# element 24 5 done ( Def. endoderm , Cardiomyocytes )
# element 24 6 done ( Def. endoderm , Pharyngeal mesoderm )
# element 24 7 done ( Def. endoderm , Nascent mesoderm )
# element 24 8 done ( Def. endoderm , Haematoendothelial progenitors )
# element 24 9 done ( Def. endoderm , Caudal epiblast )
# element 24 10 done ( Def. endoderm , Caudal Mesoderm )
# element 24 11 done ( Def. endoderm , Anterior Primitive Streak )
# element 24 12 done ( Def. endoderm , Blood progenitors 1 )
# element 24 13 done ( Def. endoderm , Allantois )
# element 24 14 done ( Def. endoderm , PGC )
# element 24 15 done ( Def. endoderm , Forebrain/Midbrain/Hindbrain )
# element 24 16 done ( Def. endoderm , Mesenchyme )
# element 24 17 done ( Def. endoderm , Primitive Streak )
# element 24 18 done ( Def. endoderm , Parietal endoderm )
# element 24 19 done ( Def. endoderm , Endothelium )
# element 24 20 done ( Def. endoderm , Spinal cord )
# element 24 21 done ( Def. endoderm , Erythroid3 )
# element 24 22 done ( Def. endoderm , Mixed mesoderm )
# element 24 23 done ( Def. endoderm , Paraxial mesoderm )
# element 25 0 done ( NMP , Blood progenitors 2 )
# element 25 1 done ( NMP , Surface ectoderm )
# element 25 2 done ( NMP , Caudal neurectoderm )
# element 25 3 done ( NMP , Rostral neurectoderm )
# element 25 4 done ( NMP , Neural crest )
# element 25 5 done ( NMP , Cardiomyocytes )
# element 25 6 done ( NMP , Pharyngeal mesoderm )
# element 25 7 done ( NMP , Nascent mesoderm )
# element 25 8 done ( NMP , Haematoendothelial progenitors )
# element 25 9 done ( NMP , Caudal epiblast )
# element 25 10 done ( NMP , Caudal Mesoderm )
# element 25 11 done ( NMP , Anterior Primitive Streak )
# element 25 12 done ( NMP , Blood progenitors 1 )
# element 25 13 done ( NMP , Allantois )
# element 25 14 done ( NMP , PGC )
# element 25 15 done ( NMP , Forebrain/Midbrain/Hindbrain )
# element 25 16 done ( NMP , Mesenchyme )
# element 25 17 done ( NMP , Primitive Streak )
# element 25 18 done ( NMP , Parietal endoderm )
# element 25 19 done ( NMP , Endothelium )
# element 25 20 done ( NMP , Spinal cord )
# element 25 21 done ( NMP , Erythroid3 )
# element 25 22 done ( NMP , Mixed mesoderm )
# element 25 23 done ( NMP , Paraxial mesoderm )
# element 25 24 done ( NMP , Def. endoderm )
# element 26 0 done ( Epiblast , Blood progenitors 2 )
# element 26 1 done ( Epiblast , Surface ectoderm )
# element 26 2 done ( Epiblast , Caudal neurectoderm )
# element 26 3 done ( Epiblast , Rostral neurectoderm )
# element 26 4 done ( Epiblast , Neural crest )
# element 26 5 done ( Epiblast , Cardiomyocytes )
# element 26 6 done ( Epiblast , Pharyngeal mesoderm )
# element 26 7 done ( Epiblast , Nascent mesoderm )
# element 26 8 done ( Epiblast , Haematoendothelial progenitors )
# element 26 9 done ( Epiblast , Caudal epiblast )
# element 26 10 done ( Epiblast , Caudal Mesoderm )
# element 26 11 done ( Epiblast , Anterior Primitive Streak )
# element 26 12 done ( Epiblast , Blood progenitors 1 )
# element 26 13 done ( Epiblast , Allantois )
# element 26 14 done ( Epiblast , PGC )
# element 26 15 done ( Epiblast , Forebrain/Midbrain/Hindbrain )
# element 26 16 done ( Epiblast , Mesenchyme )
# element 26 17 done ( Epiblast , Primitive Streak )
# element 26 18 done ( Epiblast , Parietal endoderm )
# element 26 19 done ( Epiblast , Endothelium )
# element 26 20 done ( Epiblast , Spinal cord )
# element 26 21 done ( Epiblast , Erythroid3 )
# element 26 22 done ( Epiblast , Mixed mesoderm )
# element 26 23 done ( Epiblast , Paraxial mesoderm )
# element 26 24 done ( Epiblast , Def. endoderm )
# element 26 25 done ( Epiblast , NMP )
# element 27 0 done ( Erythroid1 , Blood progenitors 2 )
# element 27 1 done ( Erythroid1 , Surface ectoderm )
# element 27 2 done ( Erythroid1 , Caudal neurectoderm )
# element 27 3 done ( Erythroid1 , Rostral neurectoderm )
# element 27 4 done ( Erythroid1 , Neural crest )
# element 27 5 done ( Erythroid1 , Cardiomyocytes )
# element 27 6 done ( Erythroid1 , Pharyngeal mesoderm )
# element 27 7 done ( Erythroid1 , Nascent mesoderm )
# element 27 8 done ( Erythroid1 , Haematoendothelial progenitors )
# element 27 9 done ( Erythroid1 , Caudal epiblast )
# element 27 10 done ( Erythroid1 , Caudal Mesoderm )
# element 27 11 done ( Erythroid1 , Anterior Primitive Streak )
# element 27 12 done ( Erythroid1 , Blood progenitors 1 )
# element 27 13 done ( Erythroid1 , Allantois )
# element 27 14 done ( Erythroid1 , PGC )
# element 27 15 done ( Erythroid1 , Forebrain/Midbrain/Hindbrain )
# element 27 16 done ( Erythroid1 , Mesenchyme )
# element 27 17 done ( Erythroid1 , Primitive Streak )
# element 27 18 done ( Erythroid1 , Parietal endoderm )
# element 27 19 done ( Erythroid1 , Endothelium )
# element 27 20 done ( Erythroid1 , Spinal cord )
# element 27 21 done ( Erythroid1 , Erythroid3 )
# element 27 22 done ( Erythroid1 , Mixed mesoderm )
# element 27 23 done ( Erythroid1 , Paraxial mesoderm )
# element 27 24 done ( Erythroid1 , Def. endoderm )
# element 27 25 done ( Erythroid1 , NMP )
# element 27 26 done ( Erythroid1 , Epiblast )
# element 28 0 done ( Visceral endoderm , Blood progenitors 2 )
# element 28 1 done ( Visceral endoderm , Surface ectoderm )
# element 28 2 done ( Visceral endoderm , Caudal neurectoderm )
# element 28 3 done ( Visceral endoderm , Rostral neurectoderm )
# element 28 4 done ( Visceral endoderm , Neural crest )
# element 28 5 done ( Visceral endoderm , Cardiomyocytes )
# element 28 6 done ( Visceral endoderm , Pharyngeal mesoderm )
# element 28 7 done ( Visceral endoderm , Nascent mesoderm )
# element 28 8 done ( Visceral endoderm , Haematoendothelial progenitors )
# element 28 9 done ( Visceral endoderm , Caudal epiblast )
# element 28 10 done ( Visceral endoderm , Caudal Mesoderm )
# element 28 11 done ( Visceral endoderm , Anterior Primitive Streak )
# element 28 12 done ( Visceral endoderm , Blood progenitors 1 )
# element 28 13 done ( Visceral endoderm , Allantois )
# element 28 14 done ( Visceral endoderm , PGC )
# element 28 15 done ( Visceral endoderm , Forebrain/Midbrain/Hindbrain )
# element 28 16 done ( Visceral endoderm , Mesenchyme )
# element 28 17 done ( Visceral endoderm , Primitive Streak )
# element 28 18 done ( Visceral endoderm , Parietal endoderm )
# element 28 19 done ( Visceral endoderm , Endothelium )
# element 28 20 done ( Visceral endoderm , Spinal cord )
# element 28 21 done ( Visceral endoderm , Erythroid3 )
# element 28 22 done ( Visceral endoderm , Mixed mesoderm )
# element 28 23 done ( Visceral endoderm , Paraxial mesoderm )
# element 28 24 done ( Visceral endoderm , Def. endoderm )
# element 28 25 done ( Visceral endoderm , NMP )
# element 28 26 done ( Visceral endoderm , Epiblast )
# element 28 27 done ( Visceral endoderm , Erythroid1 )
# element 29 0 done ( Gut , Blood progenitors 2 )
# element 29 1 done ( Gut , Surface ectoderm )
# element 29 2 done ( Gut , Caudal neurectoderm )
# element 29 3 done ( Gut , Rostral neurectoderm )
# element 29 4 done ( Gut , Neural crest )
# element 29 5 done ( Gut , Cardiomyocytes )
# element 29 6 done ( Gut , Pharyngeal mesoderm )
# element 29 7 done ( Gut , Nascent mesoderm )
# element 29 8 done ( Gut , Haematoendothelial progenitors )
# element 29 9 done ( Gut , Caudal epiblast )
# element 29 10 done ( Gut , Caudal Mesoderm )
# element 29 11 done ( Gut , Anterior Primitive Streak )
# element 29 12 done ( Gut , Blood progenitors 1 )
# element 29 13 done ( Gut , Allantois )
# element 29 14 done ( Gut , PGC )
# element 29 15 done ( Gut , Forebrain/Midbrain/Hindbrain )
# element 29 16 done ( Gut , Mesenchyme )
# element 29 17 done ( Gut , Primitive Streak )
# element 29 18 done ( Gut , Parietal endoderm )
# element 29 19 done ( Gut , Endothelium )
# element 29 20 done ( Gut , Spinal cord )
# element 29 21 done ( Gut , Erythroid3 )
# element 29 22 done ( Gut , Mixed mesoderm )
# element 29 23 done ( Gut , Paraxial mesoderm )
# element 29 24 done ( Gut , Def. endoderm )
# element 29 25 done ( Gut , NMP )
# element 29 26 done ( Gut , Epiblast )
# element 29 27 done ( Gut , Erythroid1 )
# element 29 28 done ( Gut , Visceral endoderm )
# element 30 0 done ( Notochord , Blood progenitors 2 )
# element 30 1 done ( Notochord , Surface ectoderm )
# element 30 2 done ( Notochord , Caudal neurectoderm )
# element 30 3 done ( Notochord , Rostral neurectoderm )
# element 30 4 done ( Notochord , Neural crest )
# element 30 5 done ( Notochord , Cardiomyocytes )
# element 30 6 done ( Notochord , Pharyngeal mesoderm )
# element 30 7 done ( Notochord , Nascent mesoderm )
# element 30 8 done ( Notochord , Haematoendothelial progenitors )
# element 30 9 done ( Notochord , Caudal epiblast )
# element 30 10 done ( Notochord , Caudal Mesoderm )
# element 30 11 done ( Notochord , Anterior Primitive Streak )
# element 30 12 done ( Notochord , Blood progenitors 1 )
# element 30 13 done ( Notochord , Allantois )
# element 30 14 done ( Notochord , PGC )
# element 30 15 done ( Notochord , Forebrain/Midbrain/Hindbrain )
# element 30 16 done ( Notochord , Mesenchyme )
# element 30 17 done ( Notochord , Primitive Streak )
# element 30 18 done ( Notochord , Parietal endoderm )
# element 30 19 done ( Notochord , Endothelium )
# element 30 20 done ( Notochord , Spinal cord )
# element 30 21 done ( Notochord , Erythroid3 )
# element 30 22 done ( Notochord , Mixed mesoderm )
# element 30 23 done ( Notochord , Paraxial mesoderm )
# element 30 24 done ( Notochord , Def. endoderm )
# element 30 25 done ( Notochord , NMP )
# element 30 26 done ( Notochord , Epiblast )
# element 30 27 done ( Notochord , Erythroid1 )
# element 30 28 done ( Notochord , Visceral endoderm )
# element 30 29 done ( Notochord , Gut )
# element 31 0 done ( Erythroid2 , Blood progenitors 2 )
# element 31 1 done ( Erythroid2 , Surface ectoderm )
# element 31 2 done ( Erythroid2 , Caudal neurectoderm )
# element 31 3 done ( Erythroid2 , Rostral neurectoderm )
# element 31 4 done ( Erythroid2 , Neural crest )
# element 31 5 done ( Erythroid2 , Cardiomyocytes )
# element 31 6 done ( Erythroid2 , Pharyngeal mesoderm )
# element 31 7 done ( Erythroid2 , Nascent mesoderm )
# element 31 8 done ( Erythroid2 , Haematoendothelial progenitors )
# element 31 9 done ( Erythroid2 , Caudal epiblast )
# element 31 10 done ( Erythroid2 , Caudal Mesoderm )
# element 31 11 done ( Erythroid2 , Anterior Primitive Streak )
# element 31 12 done ( Erythroid2 , Blood progenitors 1 )
# element 31 13 done ( Erythroid2 , Allantois )
# element 31 14 done ( Erythroid2 , PGC )
# element 31 15 done ( Erythroid2 , Forebrain/Midbrain/Hindbrain )
# element 31 16 done ( Erythroid2 , Mesenchyme )
# element 31 17 done ( Erythroid2 , Primitive Streak )
# element 31 18 done ( Erythroid2 , Parietal endoderm )
# element 31 19 done ( Erythroid2 , Endothelium )
# element 31 20 done ( Erythroid2 , Spinal cord )
# element 31 21 done ( Erythroid2 , Erythroid3 )
# element 31 22 done ( Erythroid2 , Mixed mesoderm )
# element 31 23 done ( Erythroid2 , Paraxial mesoderm )
# element 31 24 done ( Erythroid2 , Def. endoderm )
# element 31 25 done ( Erythroid2 , NMP )
# element 31 26 done ( Erythroid2 , Epiblast )
# element 31 27 done ( Erythroid2 , Erythroid1 )
# element 31 28 done ( Erythroid2 , Visceral endoderm )
# element 31 29 done ( Erythroid2 , Gut )
# element 31 30 done ( Erythroid2 , Notochord )
# element 32 0 done ( Intermediate mesoderm , Blood progenitors 2 )
# element 32 1 done ( Intermediate mesoderm , Surface ectoderm )
# element 32 2 done ( Intermediate mesoderm , Caudal neurectoderm )
# element 32 3 done ( Intermediate mesoderm , Rostral neurectoderm )
# element 32 4 done ( Intermediate mesoderm , Neural crest )
# element 32 5 done ( Intermediate mesoderm , Cardiomyocytes )
# element 32 6 done ( Intermediate mesoderm , Pharyngeal mesoderm )
# element 32 7 done ( Intermediate mesoderm , Nascent mesoderm )
# element 32 8 done ( Intermediate mesoderm , Haematoendothelial progenitors )
# element 32 9 done ( Intermediate mesoderm , Caudal epiblast )
# element 32 10 done ( Intermediate mesoderm , Caudal Mesoderm )
# element 32 11 done ( Intermediate mesoderm , Anterior Primitive Streak )
# element 32 12 done ( Intermediate mesoderm , Blood progenitors 1 )
# element 32 13 done ( Intermediate mesoderm , Allantois )
# element 32 14 done ( Intermediate mesoderm , PGC )
# element 32 15 done ( Intermediate mesoderm , Forebrain/Midbrain/Hindbrain )
# element 32 16 done ( Intermediate mesoderm , Mesenchyme )
# element 32 17 done ( Intermediate mesoderm , Primitive Streak )
# element 32 18 done ( Intermediate mesoderm , Parietal endoderm )
# element 32 19 done ( Intermediate mesoderm , Endothelium )
# element 32 20 done ( Intermediate mesoderm , Spinal cord )
# element 32 21 done ( Intermediate mesoderm , Erythroid3 )
# element 32 22 done ( Intermediate mesoderm , Mixed mesoderm )
# element 32 23 done ( Intermediate mesoderm , Paraxial mesoderm )
# element 32 24 done ( Intermediate mesoderm , Def. endoderm )
# element 32 25 done ( Intermediate mesoderm , NMP )
# element 32 26 done ( Intermediate mesoderm , Epiblast )
# element 32 27 done ( Intermediate mesoderm , Erythroid1 )
# element 32 28 done ( Intermediate mesoderm , Visceral endoderm )
# element 32 29 done ( Intermediate mesoderm , Gut )
# element 32 30 done ( Intermediate mesoderm , Notochord )
# element 32 31 done ( Intermediate mesoderm , Erythroid2 )
# element 33 0 done ( Somitic mesoderm , Blood progenitors 2 )
# element 33 1 done ( Somitic mesoderm , Surface ectoderm )
# element 33 2 done ( Somitic mesoderm , Caudal neurectoderm )
# element 33 3 done ( Somitic mesoderm , Rostral neurectoderm )
# element 33 4 done ( Somitic mesoderm , Neural crest )
# element 33 5 done ( Somitic mesoderm , Cardiomyocytes )
# element 33 6 done ( Somitic mesoderm , Pharyngeal mesoderm )
# element 33 7 done ( Somitic mesoderm , Nascent mesoderm )
# element 33 8 done ( Somitic mesoderm , Haematoendothelial progenitors )
# element 33 9 done ( Somitic mesoderm , Caudal epiblast )
# element 33 10 done ( Somitic mesoderm , Caudal Mesoderm )
# element 33 11 done ( Somitic mesoderm , Anterior Primitive Streak )
# element 33 12 done ( Somitic mesoderm , Blood progenitors 1 )
# element 33 13 done ( Somitic mesoderm , Allantois )
# element 33 14 done ( Somitic mesoderm , PGC )
# element 33 15 done ( Somitic mesoderm , Forebrain/Midbrain/Hindbrain )
# element 33 16 done ( Somitic mesoderm , Mesenchyme )
# element 33 17 done ( Somitic mesoderm , Primitive Streak )
# element 33 18 done ( Somitic mesoderm , Parietal endoderm )
# element 33 19 done ( Somitic mesoderm , Endothelium )
# element 33 20 done ( Somitic mesoderm , Spinal cord )
# element 33 21 done ( Somitic mesoderm , Erythroid3 )
# element 33 22 done ( Somitic mesoderm , Mixed mesoderm )
# element 33 23 done ( Somitic mesoderm , Paraxial mesoderm )
# element 33 24 done ( Somitic mesoderm , Def. endoderm )
# element 33 25 done ( Somitic mesoderm , NMP )
# element 33 26 done ( Somitic mesoderm , Epiblast )
# element 33 27 done ( Somitic mesoderm , Erythroid1 )
# element 33 28 done ( Somitic mesoderm , Visceral endoderm )
# element 33 29 done ( Somitic mesoderm , Gut )
# element 33 30 done ( Somitic mesoderm , Notochord )
# element 33 31 done ( Somitic mesoderm , Erythroid2 )
# element 33 32 done ( Somitic mesoderm , Intermediate mesoderm )
# saved cosine matrix to  mouse1_cosine_dist_matrix_DE_subset0.8.csv
# creating distance matrix number 2
# adata object created, expression matrix dimensions: (9227, 29452)
# ranking genes
#     finished (0:01:05.64) --> added to `.uns['rank_genes_groups']`
#     'names', sorted np.recarray to be indexed by group ids
#     'scores', sorted np.recarray to be indexed by group ids
#     'logfoldchanges', sorted np.recarray to be indexed by group ids
#     'pvals', sorted np.recarray to be indexed by group ids
#     'pvals_adj', sorted np.recarray to be indexed by group ids
# randomly selecting a proportion (alpha) of genes
# list of  80 % of all DE genes ( 1153  ) created, of total initial 29452 genes
# a snippet of DE_genes subset: ['ENSMUSG00000038193', 'ENSMUSG00000029922', 'ENSMUSG00000039278', 'ENSMUSG00000029413', 'ENSMUSG00000037664']
# adata object subsetted to DE genes only, dimensions: (9227, 922)
# 34 cell types: ['Blood progenitors 2', 'Surface ectoderm', 'Caudal neurectoderm', 'Rostral neurectoderm', 'Neural crest', 'Cardiomyocytes', 'Pharyngeal mesoderm', 'Nascent mesoderm', 'Haematoendothelial progenitors', 'Caudal epiblast', 'Caudal Mesoderm', 'Anterior Primitive Streak', 'Blood progenitors 1', 'Allantois', 'PGC', 'Forebrain/Midbrain/Hindbrain', 'Mesenchyme', 'Primitive Streak', 'Parietal endoderm', 'Endothelium', 'Spinal cord', 'Erythroid3', 'Mixed mesoderm', 'Paraxial mesoderm', 'Def. endoderm', 'NMP', 'Epiblast', 'Erythroid1', 'Visceral endoderm', 'Gut', 'Notochord', 'Erythroid2', 'Intermediate mesoderm', 'Somitic mesoderm']
# creating cosine similarity distance matrix
# element 1 0 done ( Surface ectoderm , Blood progenitors 2 )
# element 2 0 done ( Caudal neurectoderm , Blood progenitors 2 )
# element 2 1 done ( Caudal neurectoderm , Surface ectoderm )
# element 3 0 done ( Rostral neurectoderm , Blood progenitors 2 )
# element 3 1 done ( Rostral neurectoderm , Surface ectoderm )
# element 3 2 done ( Rostral neurectoderm , Caudal neurectoderm )
# element 4 0 done ( Neural crest , Blood progenitors 2 )
# element 4 1 done ( Neural crest , Surface ectoderm )
# element 4 2 done ( Neural crest , Caudal neurectoderm )
# element 4 3 done ( Neural crest , Rostral neurectoderm )
# element 5 0 done ( Cardiomyocytes , Blood progenitors 2 )
# element 5 1 done ( Cardiomyocytes , Surface ectoderm )
# element 5 2 done ( Cardiomyocytes , Caudal neurectoderm )
# element 5 3 done ( Cardiomyocytes , Rostral neurectoderm )
# element 5 4 done ( Cardiomyocytes , Neural crest )
# element 6 0 done ( Pharyngeal mesoderm , Blood progenitors 2 )
# element 6 1 done ( Pharyngeal mesoderm , Surface ectoderm )
# element 6 2 done ( Pharyngeal mesoderm , Caudal neurectoderm )
# element 6 3 done ( Pharyngeal mesoderm , Rostral neurectoderm )
# element 6 4 done ( Pharyngeal mesoderm , Neural crest )
# element 6 5 done ( Pharyngeal mesoderm , Cardiomyocytes )
# element 7 0 done ( Nascent mesoderm , Blood progenitors 2 )
# element 7 1 done ( Nascent mesoderm , Surface ectoderm )
# element 7 2 done ( Nascent mesoderm , Caudal neurectoderm )
# element 7 3 done ( Nascent mesoderm , Rostral neurectoderm )
# element 7 4 done ( Nascent mesoderm , Neural crest )
# element 7 5 done ( Nascent mesoderm , Cardiomyocytes )
# element 7 6 done ( Nascent mesoderm , Pharyngeal mesoderm )
# element 8 0 done ( Haematoendothelial progenitors , Blood progenitors 2 )
# element 8 1 done ( Haematoendothelial progenitors , Surface ectoderm )
# element 8 2 done ( Haematoendothelial progenitors , Caudal neurectoderm )
# element 8 3 done ( Haematoendothelial progenitors , Rostral neurectoderm )
# element 8 4 done ( Haematoendothelial progenitors , Neural crest )
# element 8 5 done ( Haematoendothelial progenitors , Cardiomyocytes )
# element 8 6 done ( Haematoendothelial progenitors , Pharyngeal mesoderm )
# element 8 7 done ( Haematoendothelial progenitors , Nascent mesoderm )
# element 9 0 done ( Caudal epiblast , Blood progenitors 2 )
# element 9 1 done ( Caudal epiblast , Surface ectoderm )
# element 9 2 done ( Caudal epiblast , Caudal neurectoderm )
# element 9 3 done ( Caudal epiblast , Rostral neurectoderm )
# element 9 4 done ( Caudal epiblast , Neural crest )
# element 9 5 done ( Caudal epiblast , Cardiomyocytes )
# element 9 6 done ( Caudal epiblast , Pharyngeal mesoderm )
# element 9 7 done ( Caudal epiblast , Nascent mesoderm )
# element 9 8 done ( Caudal epiblast , Haematoendothelial progenitors )
# element 10 0 done ( Caudal Mesoderm , Blood progenitors 2 )
# element 10 1 done ( Caudal Mesoderm , Surface ectoderm )
# element 10 2 done ( Caudal Mesoderm , Caudal neurectoderm )
# element 10 3 done ( Caudal Mesoderm , Rostral neurectoderm )
# element 10 4 done ( Caudal Mesoderm , Neural crest )
# element 10 5 done ( Caudal Mesoderm , Cardiomyocytes )
# element 10 6 done ( Caudal Mesoderm , Pharyngeal mesoderm )
# element 10 7 done ( Caudal Mesoderm , Nascent mesoderm )
# element 10 8 done ( Caudal Mesoderm , Haematoendothelial progenitors )
# element 10 9 done ( Caudal Mesoderm , Caudal epiblast )
# element 11 0 done ( Anterior Primitive Streak , Blood progenitors 2 )
# element 11 1 done ( Anterior Primitive Streak , Surface ectoderm )
# element 11 2 done ( Anterior Primitive Streak , Caudal neurectoderm )
# element 11 3 done ( Anterior Primitive Streak , Rostral neurectoderm )
# element 11 4 done ( Anterior Primitive Streak , Neural crest )
# element 11 5 done ( Anterior Primitive Streak , Cardiomyocytes )
# element 11 6 done ( Anterior Primitive Streak , Pharyngeal mesoderm )
# element 11 7 done ( Anterior Primitive Streak , Nascent mesoderm )
# element 11 8 done ( Anterior Primitive Streak , Haematoendothelial progenitors )
# element 11 9 done ( Anterior Primitive Streak , Caudal epiblast )
# element 11 10 done ( Anterior Primitive Streak , Caudal Mesoderm )
# element 12 0 done ( Blood progenitors 1 , Blood progenitors 2 )
# element 12 1 done ( Blood progenitors 1 , Surface ectoderm )
# element 12 2 done ( Blood progenitors 1 , Caudal neurectoderm )
# element 12 3 done ( Blood progenitors 1 , Rostral neurectoderm )
# element 12 4 done ( Blood progenitors 1 , Neural crest )
# element 12 5 done ( Blood progenitors 1 , Cardiomyocytes )
# element 12 6 done ( Blood progenitors 1 , Pharyngeal mesoderm )
# element 12 7 done ( Blood progenitors 1 , Nascent mesoderm )
# element 12 8 done ( Blood progenitors 1 , Haematoendothelial progenitors )
# element 12 9 done ( Blood progenitors 1 , Caudal epiblast )
# element 12 10 done ( Blood progenitors 1 , Caudal Mesoderm )
# element 12 11 done ( Blood progenitors 1 , Anterior Primitive Streak )
# element 13 0 done ( Allantois , Blood progenitors 2 )
# element 13 1 done ( Allantois , Surface ectoderm )
# element 13 2 done ( Allantois , Caudal neurectoderm )
# element 13 3 done ( Allantois , Rostral neurectoderm )
# element 13 4 done ( Allantois , Neural crest )
# element 13 5 done ( Allantois , Cardiomyocytes )
# element 13 6 done ( Allantois , Pharyngeal mesoderm )
# element 13 7 done ( Allantois , Nascent mesoderm )
# element 13 8 done ( Allantois , Haematoendothelial progenitors )
# element 13 9 done ( Allantois , Caudal epiblast )
# element 13 10 done ( Allantois , Caudal Mesoderm )
# element 13 11 done ( Allantois , Anterior Primitive Streak )
# element 13 12 done ( Allantois , Blood progenitors 1 )
# element 14 0 done ( PGC , Blood progenitors 2 )
# element 14 1 done ( PGC , Surface ectoderm )
# element 14 2 done ( PGC , Caudal neurectoderm )
# element 14 3 done ( PGC , Rostral neurectoderm )
# element 14 4 done ( PGC , Neural crest )
# element 14 5 done ( PGC , Cardiomyocytes )
# element 14 6 done ( PGC , Pharyngeal mesoderm )
# element 14 7 done ( PGC , Nascent mesoderm )
# element 14 8 done ( PGC , Haematoendothelial progenitors )
# element 14 9 done ( PGC , Caudal epiblast )
# element 14 10 done ( PGC , Caudal Mesoderm )
# element 14 11 done ( PGC , Anterior Primitive Streak )
# element 14 12 done ( PGC , Blood progenitors 1 )
# element 14 13 done ( PGC , Allantois )
# element 15 0 done ( Forebrain/Midbrain/Hindbrain , Blood progenitors 2 )
# element 15 1 done ( Forebrain/Midbrain/Hindbrain , Surface ectoderm )
# element 15 2 done ( Forebrain/Midbrain/Hindbrain , Caudal neurectoderm )
# element 15 3 done ( Forebrain/Midbrain/Hindbrain , Rostral neurectoderm )
# element 15 4 done ( Forebrain/Midbrain/Hindbrain , Neural crest )
# element 15 5 done ( Forebrain/Midbrain/Hindbrain , Cardiomyocytes )
# element 15 6 done ( Forebrain/Midbrain/Hindbrain , Pharyngeal mesoderm )
# element 15 7 done ( Forebrain/Midbrain/Hindbrain , Nascent mesoderm )
# element 15 8 done ( Forebrain/Midbrain/Hindbrain , Haematoendothelial progenitors )
# element 15 9 done ( Forebrain/Midbrain/Hindbrain , Caudal epiblast )
# element 15 10 done ( Forebrain/Midbrain/Hindbrain , Caudal Mesoderm )
# element 15 11 done ( Forebrain/Midbrain/Hindbrain , Anterior Primitive Streak )
# element 15 12 done ( Forebrain/Midbrain/Hindbrain , Blood progenitors 1 )
# element 15 13 done ( Forebrain/Midbrain/Hindbrain , Allantois )
# element 15 14 done ( Forebrain/Midbrain/Hindbrain , PGC )
# element 16 0 done ( Mesenchyme , Blood progenitors 2 )
# element 16 1 done ( Mesenchyme , Surface ectoderm )
# element 16 2 done ( Mesenchyme , Caudal neurectoderm )
# element 16 3 done ( Mesenchyme , Rostral neurectoderm )
# element 16 4 done ( Mesenchyme , Neural crest )
# element 16 5 done ( Mesenchyme , Cardiomyocytes )
# element 16 6 done ( Mesenchyme , Pharyngeal mesoderm )
# element 16 7 done ( Mesenchyme , Nascent mesoderm )
# element 16 8 done ( Mesenchyme , Haematoendothelial progenitors )
# element 16 9 done ( Mesenchyme , Caudal epiblast )
# element 16 10 done ( Mesenchyme , Caudal Mesoderm )
# element 16 11 done ( Mesenchyme , Anterior Primitive Streak )
# element 16 12 done ( Mesenchyme , Blood progenitors 1 )
# element 16 13 done ( Mesenchyme , Allantois )
# element 16 14 done ( Mesenchyme , PGC )
# element 16 15 done ( Mesenchyme , Forebrain/Midbrain/Hindbrain )
# element 17 0 done ( Primitive Streak , Blood progenitors 2 )
# element 17 1 done ( Primitive Streak , Surface ectoderm )
# element 17 2 done ( Primitive Streak , Caudal neurectoderm )
# element 17 3 done ( Primitive Streak , Rostral neurectoderm )
# element 17 4 done ( Primitive Streak , Neural crest )
# element 17 5 done ( Primitive Streak , Cardiomyocytes )
# element 17 6 done ( Primitive Streak , Pharyngeal mesoderm )
# element 17 7 done ( Primitive Streak , Nascent mesoderm )
# element 17 8 done ( Primitive Streak , Haematoendothelial progenitors )
# element 17 9 done ( Primitive Streak , Caudal epiblast )
# element 17 10 done ( Primitive Streak , Caudal Mesoderm )
# element 17 11 done ( Primitive Streak , Anterior Primitive Streak )
# element 17 12 done ( Primitive Streak , Blood progenitors 1 )
# element 17 13 done ( Primitive Streak , Allantois )
# element 17 14 done ( Primitive Streak , PGC )
# element 17 15 done ( Primitive Streak , Forebrain/Midbrain/Hindbrain )
# element 17 16 done ( Primitive Streak , Mesenchyme )
# element 18 0 done ( Parietal endoderm , Blood progenitors 2 )
# element 18 1 done ( Parietal endoderm , Surface ectoderm )
# element 18 2 done ( Parietal endoderm , Caudal neurectoderm )
# element 18 3 done ( Parietal endoderm , Rostral neurectoderm )
# element 18 4 done ( Parietal endoderm , Neural crest )
# element 18 5 done ( Parietal endoderm , Cardiomyocytes )
# element 18 6 done ( Parietal endoderm , Pharyngeal mesoderm )
# element 18 7 done ( Parietal endoderm , Nascent mesoderm )
# element 18 8 done ( Parietal endoderm , Haematoendothelial progenitors )
# element 18 9 done ( Parietal endoderm , Caudal epiblast )
# element 18 10 done ( Parietal endoderm , Caudal Mesoderm )
# element 18 11 done ( Parietal endoderm , Anterior Primitive Streak )
# element 18 12 done ( Parietal endoderm , Blood progenitors 1 )
# element 18 13 done ( Parietal endoderm , Allantois )
# element 18 14 done ( Parietal endoderm , PGC )
# element 18 15 done ( Parietal endoderm , Forebrain/Midbrain/Hindbrain )
# element 18 16 done ( Parietal endoderm , Mesenchyme )
# element 18 17 done ( Parietal endoderm , Primitive Streak )
# element 19 0 done ( Endothelium , Blood progenitors 2 )
# element 19 1 done ( Endothelium , Surface ectoderm )
# element 19 2 done ( Endothelium , Caudal neurectoderm )
# element 19 3 done ( Endothelium , Rostral neurectoderm )
# element 19 4 done ( Endothelium , Neural crest )
# element 19 5 done ( Endothelium , Cardiomyocytes )
# element 19 6 done ( Endothelium , Pharyngeal mesoderm )
# element 19 7 done ( Endothelium , Nascent mesoderm )
# element 19 8 done ( Endothelium , Haematoendothelial progenitors )
# element 19 9 done ( Endothelium , Caudal epiblast )
# element 19 10 done ( Endothelium , Caudal Mesoderm )
# element 19 11 done ( Endothelium , Anterior Primitive Streak )
# element 19 12 done ( Endothelium , Blood progenitors 1 )
# element 19 13 done ( Endothelium , Allantois )
# element 19 14 done ( Endothelium , PGC )
# element 19 15 done ( Endothelium , Forebrain/Midbrain/Hindbrain )
# element 19 16 done ( Endothelium , Mesenchyme )
# element 19 17 done ( Endothelium , Primitive Streak )
# element 19 18 done ( Endothelium , Parietal endoderm )
# element 20 0 done ( Spinal cord , Blood progenitors 2 )
# element 20 1 done ( Spinal cord , Surface ectoderm )
# element 20 2 done ( Spinal cord , Caudal neurectoderm )
# element 20 3 done ( Spinal cord , Rostral neurectoderm )
# element 20 4 done ( Spinal cord , Neural crest )
# element 20 5 done ( Spinal cord , Cardiomyocytes )
# element 20 6 done ( Spinal cord , Pharyngeal mesoderm )
# element 20 7 done ( Spinal cord , Nascent mesoderm )
# element 20 8 done ( Spinal cord , Haematoendothelial progenitors )
# element 20 9 done ( Spinal cord , Caudal epiblast )
# element 20 10 done ( Spinal cord , Caudal Mesoderm )
# element 20 11 done ( Spinal cord , Anterior Primitive Streak )
# element 20 12 done ( Spinal cord , Blood progenitors 1 )
# element 20 13 done ( Spinal cord , Allantois )
# element 20 14 done ( Spinal cord , PGC )
# element 20 15 done ( Spinal cord , Forebrain/Midbrain/Hindbrain )
# element 20 16 done ( Spinal cord , Mesenchyme )
# element 20 17 done ( Spinal cord , Primitive Streak )
# element 20 18 done ( Spinal cord , Parietal endoderm )
# element 20 19 done ( Spinal cord , Endothelium )
# element 21 0 done ( Erythroid3 , Blood progenitors 2 )
# element 21 1 done ( Erythroid3 , Surface ectoderm )
# element 21 2 done ( Erythroid3 , Caudal neurectoderm )
# element 21 3 done ( Erythroid3 , Rostral neurectoderm )
# element 21 4 done ( Erythroid3 , Neural crest )
# element 21 5 done ( Erythroid3 , Cardiomyocytes )
# element 21 6 done ( Erythroid3 , Pharyngeal mesoderm )
# element 21 7 done ( Erythroid3 , Nascent mesoderm )
# element 21 8 done ( Erythroid3 , Haematoendothelial progenitors )
# element 21 9 done ( Erythroid3 , Caudal epiblast )
# element 21 10 done ( Erythroid3 , Caudal Mesoderm )
# element 21 11 done ( Erythroid3 , Anterior Primitive Streak )
# element 21 12 done ( Erythroid3 , Blood progenitors 1 )
# element 21 13 done ( Erythroid3 , Allantois )
# element 21 14 done ( Erythroid3 , PGC )
# element 21 15 done ( Erythroid3 , Forebrain/Midbrain/Hindbrain )
# element 21 16 done ( Erythroid3 , Mesenchyme )
# element 21 17 done ( Erythroid3 , Primitive Streak )
# element 21 18 done ( Erythroid3 , Parietal endoderm )
# element 21 19 done ( Erythroid3 , Endothelium )
# element 21 20 done ( Erythroid3 , Spinal cord )
# element 22 0 done ( Mixed mesoderm , Blood progenitors 2 )
# element 22 1 done ( Mixed mesoderm , Surface ectoderm )
# element 22 2 done ( Mixed mesoderm , Caudal neurectoderm )
# element 22 3 done ( Mixed mesoderm , Rostral neurectoderm )
# element 22 4 done ( Mixed mesoderm , Neural crest )
# ...
# element 23 9 done ( Paraxial mesoderm , Caudal epiblast )
# element 23 10 done ( Paraxial mesoderm , Caudal Mesoderm )
# element 23 11 done ( Paraxial mesoderm , Anterior Primitive Streak )
# element 23 12 done ( Paraxial mesoderm , Blood progenitors 1 )
# element 23 13 done ( Paraxial mesoderm , Allantois )
# element 23 14 done ( Paraxial mesoderm , PGC )
# element 23 15 done ( Paraxial mesoderm , Forebrain/Midbrain/Hindbrain )
# element 23 16 done ( Paraxial mesoderm , Mesenchyme )
# element 23 17 done ( Paraxial mesoderm , Primitive Streak )
# element 23 18 done ( Paraxial mesoderm , Parietal endoderm )
# element 23 19 done ( Paraxial mesoderm , Endothelium )
# element 23 20 done ( Paraxial mesoderm , Spinal cord )
# element 23 21 done ( Paraxial mesoderm , Erythroid3 )
# element 23 22 done ( Paraxial mesoderm , Mixed mesoderm )
# element 24 0 done ( Def. endoderm , Blood progenitors 2 )
# element 24 1 done ( Def. endoderm , Surface ectoderm )
# element 24 2 done ( Def. endoderm , Caudal neurectoderm )
# element 24 3 done ( Def. endoderm , Rostral neurectoderm )
# element 24 4 done ( Def. endoderm , Neural crest )
# element 24 5 done ( Def. endoderm , Cardiomyocytes )
# element 24 6 done ( Def. endoderm , Pharyngeal mesoderm )
# element 24 7 done ( Def. endoderm , Nascent mesoderm )
# element 24 8 done ( Def. endoderm , Haematoendothelial progenitors )
# element 24 9 done ( Def. endoderm , Caudal epiblast )
# element 24 10 done ( Def. endoderm , Caudal Mesoderm )
# element 24 11 done ( Def. endoderm , Anterior Primitive Streak )
# element 24 12 done ( Def. endoderm , Blood progenitors 1 )
# element 24 13 done ( Def. endoderm , Allantois )
# element 24 14 done ( Def. endoderm , PGC )
# element 24 15 done ( Def. endoderm , Forebrain/Midbrain/Hindbrain )
# element 24 16 done ( Def. endoderm , Mesenchyme )
# element 24 17 done ( Def. endoderm , Primitive Streak )
# element 24 18 done ( Def. endoderm , Parietal endoderm )
# element 24 19 done ( Def. endoderm , Endothelium )
# element 24 20 done ( Def. endoderm , Spinal cord )
# element 24 21 done ( Def. endoderm , Erythroid3 )
# element 24 22 done ( Def. endoderm , Mixed mesoderm )
# element 24 23 done ( Def. endoderm , Paraxial mesoderm )
# element 25 0 done ( NMP , Blood progenitors 2 )
# element 25 1 done ( NMP , Surface ectoderm )
# element 25 2 done ( NMP , Caudal neurectoderm )
# element 25 3 done ( NMP , Rostral neurectoderm )
# element 25 4 done ( NMP , Neural crest )
# element 25 5 done ( NMP , Cardiomyocytes )
# element 25 6 done ( NMP , Pharyngeal mesoderm )
# element 25 7 done ( NMP , Nascent mesoderm )
# element 25 8 done ( NMP , Haematoendothelial progenitors )
# element 25 9 done ( NMP , Caudal epiblast )
# element 25 10 done ( NMP , Caudal Mesoderm )
# element 25 11 done ( NMP , Anterior Primitive Streak )
# element 25 12 done ( NMP , Blood progenitors 1 )
# element 25 13 done ( NMP , Allantois )
# element 25 14 done ( NMP , PGC )
# element 25 15 done ( NMP , Forebrain/Midbrain/Hindbrain )
# element 25 16 done ( NMP , Mesenchyme )
# element 25 17 done ( NMP , Primitive Streak )
# element 25 18 done ( NMP , Parietal endoderm )
# element 25 19 done ( NMP , Endothelium )
# element 25 20 done ( NMP , Spinal cord )
# element 25 21 done ( NMP , Erythroid3 )
# element 25 22 done ( NMP , Mixed mesoderm )
# element 25 23 done ( NMP , Paraxial mesoderm )
# element 25 24 done ( NMP , Def. endoderm )
# element 26 0 done ( Epiblast , Blood progenitors 2 )
# element 26 1 done ( Epiblast , Surface ectoderm )
# element 26 2 done ( Epiblast , Caudal neurectoderm )
# element 26 3 done ( Epiblast , Rostral neurectoderm )
# element 26 4 done ( Epiblast , Neural crest )
# element 26 5 done ( Epiblast , Cardiomyocytes )
# element 26 6 done ( Epiblast , Pharyngeal mesoderm )
# element 26 7 done ( Epiblast , Nascent mesoderm )
# element 26 8 done ( Epiblast , Haematoendothelial progenitors )
# element 26 9 done ( Epiblast , Caudal epiblast )
# element 26 10 done ( Epiblast , Caudal Mesoderm )
# element 26 11 done ( Epiblast , Anterior Primitive Streak )
# element 26 12 done ( Epiblast , Blood progenitors 1 )
# element 26 13 done ( Epiblast , Allantois )
# element 26 14 done ( Epiblast , PGC )
# element 26 15 done ( Epiblast , Forebrain/Midbrain/Hindbrain )
# element 26 16 done ( Epiblast , Mesenchyme )
# element 26 17 done ( Epiblast , Primitive Streak )
# element 26 18 done ( Epiblast , Parietal endoderm )
# element 26 19 done ( Epiblast , Endothelium )
# element 26 20 done ( Epiblast , Spinal cord )
# element 26 21 done ( Epiblast , Erythroid3 )
# element 26 22 done ( Epiblast , Mixed mesoderm )
# element 26 23 done ( Epiblast , Paraxial mesoderm )
# element 26 24 done ( Epiblast , Def. endoderm )
# element 26 25 done ( Epiblast , NMP )
# element 27 0 done ( Erythroid1 , Blood progenitors 2 )
# element 27 1 done ( Erythroid1 , Surface ectoderm )
# element 27 2 done ( Erythroid1 , Caudal neurectoderm )
# element 27 3 done ( Erythroid1 , Rostral neurectoderm )
# element 27 4 done ( Erythroid1 , Neural crest )
# element 27 5 done ( Erythroid1 , Cardiomyocytes )
# element 27 6 done ( Erythroid1 , Pharyngeal mesoderm )
# element 27 7 done ( Erythroid1 , Nascent mesoderm )
# element 27 8 done ( Erythroid1 , Haematoendothelial progenitors )
# element 27 9 done ( Erythroid1 , Caudal epiblast )
# element 27 10 done ( Erythroid1 , Caudal Mesoderm )
# element 27 11 done ( Erythroid1 , Anterior Primitive Streak )
# element 27 12 done ( Erythroid1 , Blood progenitors 1 )
# element 27 13 done ( Erythroid1 , Allantois )
# element 27 14 done ( Erythroid1 , PGC )
# element 27 15 done ( Erythroid1 , Forebrain/Midbrain/Hindbrain )
# element 27 16 done ( Erythroid1 , Mesenchyme )
# element 27 17 done ( Erythroid1 , Primitive Streak )
# element 27 18 done ( Erythroid1 , Parietal endoderm )
# element 27 19 done ( Erythroid1 , Endothelium )
# element 27 20 done ( Erythroid1 , Spinal cord )
# element 27 21 done ( Erythroid1 , Erythroid3 )
# element 27 22 done ( Erythroid1 , Mixed mesoderm )
# element 27 23 done ( Erythroid1 , Paraxial mesoderm )
# element 27 24 done ( Erythroid1 , Def. endoderm )
# element 27 25 done ( Erythroid1 , NMP )
# element 27 26 done ( Erythroid1 , Epiblast )
# element 28 0 done ( Visceral endoderm , Blood progenitors 2 )
# element 28 1 done ( Visceral endoderm , Surface ectoderm )
# element 28 2 done ( Visceral endoderm , Caudal neurectoderm )
# element 28 3 done ( Visceral endoderm , Rostral neurectoderm )
# element 28 4 done ( Visceral endoderm , Neural crest )
# element 28 5 done ( Visceral endoderm , Cardiomyocytes )
# element 28 6 done ( Visceral endoderm , Pharyngeal mesoderm )
# element 28 7 done ( Visceral endoderm , Nascent mesoderm )
# element 28 8 done ( Visceral endoderm , Haematoendothelial progenitors )
# element 28 9 done ( Visceral endoderm , Caudal epiblast )
# element 28 10 done ( Visceral endoderm , Caudal Mesoderm )
# element 28 11 done ( Visceral endoderm , Anterior Primitive Streak )
# element 28 12 done ( Visceral endoderm , Blood progenitors 1 )
# element 28 13 done ( Visceral endoderm , Allantois )
# element 28 14 done ( Visceral endoderm , PGC )
# element 28 15 done ( Visceral endoderm , Forebrain/Midbrain/Hindbrain )
# element 28 16 done ( Visceral endoderm , Mesenchyme )
# element 28 17 done ( Visceral endoderm , Primitive Streak )
# element 28 18 done ( Visceral endoderm , Parietal endoderm )
# element 28 19 done ( Visceral endoderm , Endothelium )
# element 28 20 done ( Visceral endoderm , Spinal cord )
# element 28 21 done ( Visceral endoderm , Erythroid3 )
# element 28 22 done ( Visceral endoderm , Mixed mesoderm )
# element 28 23 done ( Visceral endoderm , Paraxial mesoderm )
# element 28 24 done ( Visceral endoderm , Def. endoderm )
# element 28 25 done ( Visceral endoderm , NMP )
# element 28 26 done ( Visceral endoderm , Epiblast )
# element 28 27 done ( Visceral endoderm , Erythroid1 )
# element 29 0 done ( Gut , Blood progenitors 2 )
# element 29 1 done ( Gut , Surface ectoderm )
# element 29 2 done ( Gut , Caudal neurectoderm )
# element 29 3 done ( Gut , Rostral neurectoderm )
# element 29 4 done ( Gut , Neural crest )
# element 29 5 done ( Gut , Cardiomyocytes )
# element 29 6 done ( Gut , Pharyngeal mesoderm )
# element 29 7 done ( Gut , Nascent mesoderm )
# element 29 8 done ( Gut , Haematoendothelial progenitors )
# element 29 9 done ( Gut , Caudal epiblast )
# element 29 10 done ( Gut , Caudal Mesoderm )
# element 29 11 done ( Gut , Anterior Primitive Streak )
# element 29 12 done ( Gut , Blood progenitors 1 )
# element 29 13 done ( Gut , Allantois )
# element 29 14 done ( Gut , PGC )
# element 29 15 done ( Gut , Forebrain/Midbrain/Hindbrain )
# element 29 16 done ( Gut , Mesenchyme )
# element 29 17 done ( Gut , Primitive Streak )
# element 29 18 done ( Gut , Parietal endoderm )
# element 29 19 done ( Gut , Endothelium )
# element 29 20 done ( Gut , Spinal cord )
# element 29 21 done ( Gut , Erythroid3 )
# element 29 22 done ( Gut , Mixed mesoderm )
# element 29 23 done ( Gut , Paraxial mesoderm )
# element 29 24 done ( Gut , Def. endoderm )
# element 29 25 done ( Gut , NMP )
# element 29 26 done ( Gut , Epiblast )
# element 29 27 done ( Gut , Erythroid1 )
# element 29 28 done ( Gut , Visceral endoderm )
# element 30 0 done ( Notochord , Blood progenitors 2 )
# element 30 1 done ( Notochord , Surface ectoderm )
# element 30 2 done ( Notochord , Caudal neurectoderm )
# element 30 3 done ( Notochord , Rostral neurectoderm )
# element 30 4 done ( Notochord , Neural crest )
# element 30 5 done ( Notochord , Cardiomyocytes )
# element 30 6 done ( Notochord , Pharyngeal mesoderm )
# element 30 7 done ( Notochord , Nascent mesoderm )
# element 30 8 done ( Notochord , Haematoendothelial progenitors )
# element 30 9 done ( Notochord , Caudal epiblast )
# element 30 10 done ( Notochord , Caudal Mesoderm )
# element 30 11 done ( Notochord , Anterior Primitive Streak )
# element 30 12 done ( Notochord , Blood progenitors 1 )
# element 30 13 done ( Notochord , Allantois )
# element 30 14 done ( Notochord , PGC )
# element 30 15 done ( Notochord , Forebrain/Midbrain/Hindbrain )
# element 30 16 done ( Notochord , Mesenchyme )
# element 30 17 done ( Notochord , Primitive Streak )
# element 30 18 done ( Notochord , Parietal endoderm )
# element 30 19 done ( Notochord , Endothelium )
# element 30 20 done ( Notochord , Spinal cord )
# element 30 21 done ( Notochord , Erythroid3 )
# element 30 22 done ( Notochord , Mixed mesoderm )
# element 30 23 done ( Notochord , Paraxial mesoderm )
# element 30 24 done ( Notochord , Def. endoderm )
# element 30 25 done ( Notochord , NMP )
# element 30 26 done ( Notochord , Epiblast )
# element 30 27 done ( Notochord , Erythroid1 )
# element 30 28 done ( Notochord , Visceral endoderm )
# element 30 29 done ( Notochord , Gut )
# element 31 0 done ( Erythroid2 , Blood progenitors 2 )
# element 31 1 done ( Erythroid2 , Surface ectoderm )
# element 31 2 done ( Erythroid2 , Caudal neurectoderm )
# element 31 3 done ( Erythroid2 , Rostral neurectoderm )
# element 31 4 done ( Erythroid2 , Neural crest )
# element 31 5 done ( Erythroid2 , Cardiomyocytes )
# element 31 6 done ( Erythroid2 , Pharyngeal mesoderm )
# element 31 7 done ( Erythroid2 , Nascent mesoderm )
# element 31 8 done ( Erythroid2 , Haematoendothelial progenitors )
# element 31 9 done ( Erythroid2 , Caudal epiblast )
# element 31 10 done ( Erythroid2 , Caudal Mesoderm )
# element 31 11 done ( Erythroid2 , Anterior Primitive Streak )
# element 31 12 done ( Erythroid2 , Blood progenitors 1 )
# element 31 13 done ( Erythroid2 , Allantois )
# element 31 14 done ( Erythroid2 , PGC )
# element 31 15 done ( Erythroid2 , Forebrain/Midbrain/Hindbrain )
# element 31 16 done ( Erythroid2 , Mesenchyme )
# element 31 17 done ( Erythroid2 , Primitive Streak )
# element 31 18 done ( Erythroid2 , Parietal endoderm )
# element 31 19 done ( Erythroid2 , Endothelium )
# element 31 20 done ( Erythroid2 , Spinal cord )
# element 31 21 done ( Erythroid2 , Erythroid3 )
# element 31 22 done ( Erythroid2 , Mixed mesoderm )
# element 31 23 done ( Erythroid2 , Paraxial mesoderm )
# element 31 24 done ( Erythroid2 , Def. endoderm )
# element 31 25 done ( Erythroid2 , NMP )
# element 31 26 done ( Erythroid2 , Epiblast )
# element 31 27 done ( Erythroid2 , Erythroid1 )
# element 31 28 done ( Erythroid2 , Visceral endoderm )
# element 31 29 done ( Erythroid2 , Gut )
# element 31 30 done ( Erythroid2 , Notochord )
# element 32 0 done ( Intermediate mesoderm , Blood progenitors 2 )
# element 32 1 done ( Intermediate mesoderm , Surface ectoderm )
# element 32 2 done ( Intermediate mesoderm , Caudal neurectoderm )
# element 32 3 done ( Intermediate mesoderm , Rostral neurectoderm )
# element 32 4 done ( Intermediate mesoderm , Neural crest )
# element 32 5 done ( Intermediate mesoderm , Cardiomyocytes )
# element 32 6 done ( Intermediate mesoderm , Pharyngeal mesoderm )
# element 32 7 done ( Intermediate mesoderm , Nascent mesoderm )
# element 32 8 done ( Intermediate mesoderm , Haematoendothelial progenitors )
# element 32 9 done ( Intermediate mesoderm , Caudal epiblast )
# element 32 10 done ( Intermediate mesoderm , Caudal Mesoderm )
# element 32 11 done ( Intermediate mesoderm , Anterior Primitive Streak )
# element 32 12 done ( Intermediate mesoderm , Blood progenitors 1 )
# element 32 13 done ( Intermediate mesoderm , Allantois )
# element 32 14 done ( Intermediate mesoderm , PGC )
# element 32 15 done ( Intermediate mesoderm , Forebrain/Midbrain/Hindbrain )
# element 32 16 done ( Intermediate mesoderm , Mesenchyme )
# element 32 17 done ( Intermediate mesoderm , Primitive Streak )
# element 32 18 done ( Intermediate mesoderm , Parietal endoderm )
# element 32 19 done ( Intermediate mesoderm , Endothelium )
# element 32 20 done ( Intermediate mesoderm , Spinal cord )
# element 32 21 done ( Intermediate mesoderm , Erythroid3 )
# element 32 22 done ( Intermediate mesoderm , Mixed mesoderm )
# element 32 23 done ( Intermediate mesoderm , Paraxial mesoderm )
# element 32 24 done ( Intermediate mesoderm , Def. endoderm )
# element 32 25 done ( Intermediate mesoderm , NMP )
# element 32 26 done ( Intermediate mesoderm , Epiblast )
# element 32 27 done ( Intermediate mesoderm , Erythroid1 )
# element 32 28 done ( Intermediate mesoderm , Visceral endoderm )
# element 32 29 done ( Intermediate mesoderm , Gut )
# element 32 30 done ( Intermediate mesoderm , Notochord )
# element 32 31 done ( Intermediate mesoderm , Erythroid2 )
# element 33 0 done ( Somitic mesoderm , Blood progenitors 2 )
# element 33 1 done ( Somitic mesoderm , Surface ectoderm )
# element 33 2 done ( Somitic mesoderm , Caudal neurectoderm )
# element 33 3 done ( Somitic mesoderm , Rostral neurectoderm )
# element 33 4 done ( Somitic mesoderm , Neural crest )
# element 33 5 done ( Somitic mesoderm , Cardiomyocytes )
# element 33 6 done ( Somitic mesoderm , Pharyngeal mesoderm )
# element 33 7 done ( Somitic mesoderm , Nascent mesoderm )
# element 33 8 done ( Somitic mesoderm , Haematoendothelial progenitors )
# element 33 9 done ( Somitic mesoderm , Caudal epiblast )
# element 33 10 done ( Somitic mesoderm , Caudal Mesoderm )
# element 33 11 done ( Somitic mesoderm , Anterior Primitive Streak )
# element 33 12 done ( Somitic mesoderm , Blood progenitors 1 )
# element 33 13 done ( Somitic mesoderm , Allantois )
# element 33 14 done ( Somitic mesoderm , PGC )
# element 33 15 done ( Somitic mesoderm , Forebrain/Midbrain/Hindbrain )
# element 33 16 done ( Somitic mesoderm , Mesenchyme )
# element 33 17 done ( Somitic mesoderm , Primitive Streak )
# element 33 18 done ( Somitic mesoderm , Parietal endoderm )
# element 33 19 done ( Somitic mesoderm , Endothelium )
# element 33 20 done ( Somitic mesoderm , Spinal cord )
# element 33 21 done ( Somitic mesoderm , Erythroid3 )
# element 33 22 done ( Somitic mesoderm , Mixed mesoderm )
# element 33 23 done ( Somitic mesoderm , Paraxial mesoderm )
# element 33 24 done ( Somitic mesoderm , Def. endoderm )
# element 33 25 done ( Somitic mesoderm , NMP )
# element 33 26 done ( Somitic mesoderm , Epiblast )
# element 33 27 done ( Somitic mesoderm , Erythroid1 )
# element 33 28 done ( Somitic mesoderm , Visceral endoderm )
# element 33 29 done ( Somitic mesoderm , Gut )
# element 33 30 done ( Somitic mesoderm , Notochord )
# element 33 31 done ( Somitic mesoderm , Erythroid2 )
# element 33 32 done ( Somitic mesoderm , Intermediate mesoderm )
# saved cosine matrix to  mouse100_cosine_dist_matrix_DE_subset0.8.csv

# %%
# %%time
# started at 13:32 18.05.19
# 100 times for planaria, cosine
# now 97 (from i=27 to i=99) because 27 trees we've already created and saved 
for i in range(27,100):
    print('creating distance matrix number',i+1)
    sc_to_dist_subset('cell_type1',['cosine'],'planaria'+str(i+1),filepath_h5ad='/home/jovyan/notebooks/Tree_of_Cells/Planaria.h5ad')
# Out:
# creating distance matrix number 28
# adata object created, expression matrix dimensions: (21612, 28065)
# ranking genes
#     finished (0:03:42.56) --> added to `.uns['rank_genes_groups']`
#     'names', sorted np.recarray to be indexed by group ids
#     'scores', sorted np.recarray to be indexed by group ids
#     'logfoldchanges', sorted np.recarray to be indexed by group ids
#     'pvals', sorted np.recarray to be indexed by group ids
#     'pvals_adj', sorted np.recarray to be indexed by group ids
# randomly selecting a proportion (alpha) of genes
# list of  80 % of all DE genes ( 1629  ) created, of total initial 28065 genes
# a snippet of DE_genes subset: ['dd_Smed_v6_1240_0', 'dd_Smed_v6_2024_0', 'dd_Smed_v6_250_0', 'dd_Smed_v6_6287_0', 'dd_Smed_v6_181_0']
# adata object subsetted to DE genes only, dimensions: (21612, 1303)
# 51 cell types: ['parenchymal progenitors', 'secretory 1', 'pigment', 'neural progenitors', 'ChAT neurons 1', 'otf+ cells 2', 'otf+ cells 1', 'muscle progenitors', 'pharynx cell type', 'activated early epidermal progenitors', 'goblet cells', 'neoblast 8', 'neoblast 7', 'muscle pharynx', 'secretory 4', 'cav-1+ neurons', 'secretory 2', 'late epidermal progenitors 1', 'gut progenitors', 'GABA neurons', 'neoblast 11', 'muscle body', 'protonephridia', 'npp-18+ neurons', 'neoblast 5', 'pharynx cell type progenitors', 'epidermis DVb', 'glia', 'secretory 3', 'pgrn+ parenchymal cells', 'neoblast 12', 'ChAT neurons 2', 'epidermis', 'neoblast 4', 'late epidermal progenitors 2', 'neoblast 10', 'neoblast 9', 'psap+ parenchymal cells', 'early epidermal progenitors', 'psd+ cells', 'aqp+ parenchymal cells', 'neoblast 6', 'spp-11+ neurons', 'neoblast 2', 'phagocytes', 'epidermal neoblasts', 'ldlrr-1+ parenchymal cells', 'neoblast 3', 'epidermis DVb neoblast', 'neoblast 13', 'neoblast 1']

# %%
# %%time
# 100 times for Sim_1112, cosine
for i in range(100):
    print('creating distance matrix number',i+1)
    sc_to_dist_subset('Group',['cosine'],'Sim_1112_'+str(i+1),
                      filepath_X_csv = '/home/jovyan/notebooks/Tree_of_Cells/Simulations_Tallulah/Sim_1112_X.csv',
                      filepath_obs_csv = '/home/jovyan/notebooks/Tree_of_Cells/Simulations_Tallulah/Sim_1112_obs.csv')

# %%
# %%time
# 100 times for Sim_3814, cosine
for i in range(100):
    print('creating distance matrix number',i+1)
    sc_to_dist_subset('Group',['cosine'],'Sim_3814_'+str(i+1),
                      filepath_X_csv = '/home/jovyan/notebooks/Tree_of_Cells/Simulations_Tallulah/Sim_3814_X.csv',
                      filepath_obs_csv = '/home/jovyan/notebooks/Tree_of_Cells/Simulations_Tallulah/Sim_3814_obs.csv')

# %%
# %%time
# 100 times for Sim_528, cosine
for i in range(100):
    print('creating distance matrix number',i+1)
    sc_to_dist_subset('Group',['cosine'],'Sim_528_'+str(i+1),
                      filepath_X_csv = '/home/jovyan/notebooks/Tree_of_Cells/Simulations_Tallulah/Sim_528_X.csv',
                      filepath_obs_csv = '/home/jovyan/notebooks/Tree_of_Cells/Simulations_Tallulah/Sim_528_obs.csv')

# %%
# %%time
# 100 times for Sim_71640, cosine
for i in range(100):
    print('creating distance matrix number',i+1)
    sc_to_dist_subset('Group',['cosine'],'Sim_71640_'+str(i+1),
                      filepath_X_csv = '/home/jovyan/notebooks/Tree_of_Cells/Simulations_Tallulah/Sim_71640_X.csv',
                      filepath_obs_csv = '/home/jovyan/notebooks/Tree_of_Cells/Simulations_Tallulah/Sim_71640_obs.csv')

# %%
# %%time
# 100 times for Sim_9901, cosine
for i in range(100):
    print('creating distance matrix number',i+1)
    sc_to_dist_subset('Group',['cosine'],'Sim_9901_'+str(i+1),
                      filepath_X_csv = '/home/jovyan/notebooks/Tree_of_Cells/Simulations_Tallulah/Sim_9901_X.csv',
                      filepath_obs_csv = '/home/jovyan/notebooks/Tree_of_Cells/Simulations_Tallulah/Sim_9901_obs.csv')
